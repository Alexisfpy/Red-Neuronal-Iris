# %% [markdown]
# # Tarea 69 - Iris Dataset
# Implementa usando PyTorch y siguiendo la domcumentación un clasificador para el dataset Iris.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt

import torch
from torch.utils.data import Dataset

import torch.nn.functional as F
import torch.nn as nn
from torch.utils.data import random_split
from torch.utils.tensorboard import SummaryWriter

# %% [markdown]
# ## Pasos previos
# 1. Cargar o dataset
# 2. Esudiarlo: Ver algún dato, pintar alguna gráfica
# 3. Tranformación de datos

# %% [markdown]
# ### Importar dataset Iris

# %%
irisDataset = pd.read_csv("../data/iris/iris.data", #TODO: aperez: Poner dos puntos para que salga de notebooks y entre en data
                          names=["sepallength","sepalwidth",
                                 "petallength","petalwidth","class"])

# %% [markdown]
# ### Estudio dataset. Datos, mostrar gráficas...

# %%
irisDataset.head(4)
# Out:
#    sepallength  sepalwidth  petallength  petalwidth        class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa

# %%
plt.style.use('ggplot')
nomeClases = irisDataset["class"].unique()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for target, target_name in enumerate(nomeClases):
    X_plot = irisDataset[irisDataset["class"] == target_name]
    ax1.plot(X_plot["sepallength"], X_plot["sepalwidth"], 
             linestyle='none', 
             marker='o', 
             label=target_name)
ax1.set_xlabel("sepallength")
ax1.set_ylabel("sepalwidth")
ax1.axis('equal')
ax1.legend()

# %% [markdown]
# ### Trasformación de Datos

# %% [markdown]
# Para trabajar bien con los datos de una red de neuronas, tenenmos que hacer alguna que otra transformación en los datos de entrada
# - No podemos trabajar con entradas categóricas (class)
# - Los valores de entrada están mejor con media 0 y desviación típica 1
# Se puede hacer una clase que haga transformación del tipo de otro frameworks

# %%
class StandardScaler:

    def __init__(self, mean=None, std=None, epsilon=1e-7):
        """Standard Scaler.
        The class can be used to normalize PyTorch Tensors using native functions. The module does not expect the
        tensors to be of any specific shape; as long as the features are the last dimension in the tensor, the module
        will work fine.
        :param mean: The mean of the features. The property will be set after a call to fit.
        :param std: The standard deviation of the features. The property will be set after a call to fit.
        :param epsilon: Used to avoid a Division-By-Zero exception.
        """
        self.mean = mean
        self.std = std
        self.epsilon = epsilon
    def fit(self, values):
        dims = list(range(values.dim() - 1))
        self.mean = torch.mean(values, dim=dims)
        self.std = torch.std(values, dim=dims)
    def transform(self, values):
        return (values - self.mean) / (self.std + self.epsilon)

    def fit_transform(self, values):
        self.fit(values)
        return self.transform(values)

    def __repr__(self):
        return f"mean: {self.mean}, std:{self.std}, epsilon:{self.epsilon}"

# %% [markdown]
# ### Datasets en PyTorch

# %% [markdown]
# Para evitar que el código de lectura de datos se vuelva caótico y difícil de mantener, PyTorch centraliza este proceso usando Datasets y DataLoaders.
# - **El rol del Dataset**: Es el objeto responsable de almacenar, leer y adaptar la información. PyTorch no hace distinción entre sus Datasets predefinidos y los que tú decidas crear desde cero; ambos se tratan igual en el ecosistema.
# - **Creación de un Dataset personalizado**: Para hacer uno propio, debes crear una clase en Python que herede de torch.utils.data.Dataset.
# Esta clase personalizada debe implementar obligatoriamente tres métodos fundamentales:
# 1. __ init__: Es el constructor. Aquí debes leer los datos originales y dejarlos preparados en memoria.
# 2. __ len__: Debe devolver el número total de patrones o muestras que tiene tu conjunto de datos.
# 3. __ getitem__: Es el encargado de extraer y devolver un patrón o muestra individual cuando se le pide.

# %%
class IrisDataset(Dataset):
  def __init__(self, src_file, root_dir, transform=None):
    irisDataset = pd.read_csv(src_file, names=["sepallength","sepalwidth","petallength","petalwidth","class"])
    X = irisDataset[irisDataset.columns.intersection(["sepallength","sepalwidth","petallength","petalwidth"])]
    Y = irisDataset[irisDataset.columns.intersection(["class"])]
    nomeClases = Y["class"].unique()
    conversion = {v: k for k, v in dict(enumerate(nomeClases)).items()}
    YConversion = pd.DataFrame()
    for nome in nomeClases:
      YConversion[nome] = (Y["class"]==nome).apply(lambda x : 1.0 if x else 0.0)
    y_tensor = torch.as_tensor(YConversion.to_numpy()).type(torch.float32)
    df_dict = dict.fromkeys(X.columns, '')
    X.rename(columns = df_dict)
    s1=X.iloc[:,0:4].values
    x_tensor = torch.tensor(s1)
    scaler = StandardScaler()
    scaler.fit(x_tensor)
    XScalada = scaler.fit_transform(x_tensor).type(torch.float32)
    self.data = torch.cat((XScalada,y_tensor),1)
    self.root_dir = root_dir
    self.transform = transform
  def __len__(self):
    return len(self.data)

  def __getitem__(self, idx):
    if torch.is_tensor(idx):
      idx = idx.tolist()
    preds = self.data[idx, 0:4]
    spcs = self.data[idx, 4:]
    sample = (preds, spcs)
    if self.transform:
      sample = self.transform(sample)
    return sample

# %% [markdown]
# ### Carga de datos por IrisDataset

# %% [markdown]
# No viene mal acceder al primer elemento, por ver si algo sale mal

# %%
dataset = IrisDataset("../data/iris/iris.data",".")
display(dataset[0]) # comprobamos que sale algo
# Out:
# (tensor([-0.8977,  1.0286, -1.3368, -1.3086]), tensor([1., 0., 0.]))

# %% [markdown]
# ## División en Train y Test
# - No se puede añadir elementos a untensor después de la creación
# - Pero podemos crear un nuevo tensor que una dos tensor, para eso está la función **cat**

# %%
lonxitudeDataset = len(dataset)
tamTrain =int(lonxitudeDataset*0.8)
tamVal = int(lonxitudeDataset*0.2)

train_set, val_set = random_split(dataset, [tamTrain, tamVal]) # TODO: aperez: Faltaba esta linea para futuros proyectos

print(f"Tam dataset: {lonxitudeDataset} train: {tamTrain} tamVal: {tamVal}")
train_ldr = torch.utils.data.DataLoader(train_set, batch_size=2,
    shuffle=True, drop_last=False)
# TODO: aperez: num_workers=2 -> S.O: Linux o macOS, PyTorch puede crear "clones" (forks) del proceso principal muy fácilmente para que carguen los datos en paralelo
#               En Windowns maneja el multiprocesamiento de forma diferente (usa algo llamado spawn). Al intentar crear estos subprocesos dentro de un Notebook, 
#               Windows se lía intentando recargar todo tu código desde cero, y los trabajadores colapsan. Ponemos a 0!!

# validation_loader =torch.utils.data.DataLoader(val_set, batch_size=4, shuffle=False, num_workers=2)
validation_loader =torch.utils.data.DataLoader(val_set, batch_size=4, shuffle=False, num_workers=0)
# Out:
# Tam dataset: 150 train: 120 tamVal: 30

# %% [markdown]
# ## Creación del Modelo
# - El modelo tiene que derivar de la clase **torch.nn.Module**
# - Deberiamos tener el método __ init__ y el método **forward**
#     - En init hay que definir la estructura del modelo: capas que tiene, tipo de capa, elementos en cada capa
#     - En forward hay que indicar como se hace el cálculo cara delante: a partir de una entrada obtener la salida

# %%
class Model(nn.Module):
    def __init__(self, input_dim):
        super(Model, self).__init__()
        self.layer1 = nn.Linear(input_dim, 50)
        self.layer2 = nn.Linear(50, 50)
        self.layer3 = nn.Linear(in_features=50, out_features=3)
        
    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        x = F.softmax(self.layer3(x), dim=1)
        return x

# %% [markdown]
# - Para las capas usamos *Linear*
#     - El primer parámetro es el tamaño de entrada
#     - El segundo parámetro es la salida
# - Para el cálculo de la salida usamos relu e softmax

# %% [markdown]
# ## Instanciar el Modelo
# - Una vez instanciado el modelo hay:
#     - Instanciarlo
#     - Definir el optimizador
#     - Definir la función de error
# - Para este dataset utilizaremos optimizadores **Adam** y **CrossEntropyLoss**

# %%
model     = Model(4) #TODO: aperez: IMPORTANTE!! Tiene que coincidir con el número de características de entrada (features) que tiene cada patrón
                     # Al ser el datset de Iris , tiene 4 
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn   = nn.CrossEntropyLoss()
display(model)
# Out:
# Model(
#   (layer1): Linear(in_features=4, out_features=50, bias=True)
#   (layer2): Linear(in_features=50, out_features=50, bias=True)
#   (layer3): Linear(in_features=50, out_features=3, bias=True)
# )

# %% [markdown]
# ### Prueba
# No está de más probar que todo en este proceso encaja y hacer una simulación de una iteración de entrenamientoss

# %%
entradaProba,dest = next(iter(train_ldr))
print("Entrada:")
display(entradaProba)
print("Desexada:")
display(dest)
saida = model(entradaProba) # esta é a proba de verdade
print("Saída:")
display(saida)
loss_fn(saida, dest)
# Out:
# Entrada:
# tensor([[ 1.0345, -0.1245,  0.8169,  1.4431],
#         [ 0.5515,  0.5674,  0.5335,  0.5259]])
# Desexada:
# tensor([[0., 0., 1.],
#         [0., 1., 0.]])
# Saída:
# tensor([[0.3627, 0.3239, 0.3134],
#         [0.3622, 0.3321, 0.3057]], grad_fn=<SoftmaxBackward0>)
# tensor(1.1094, grad_fn=<DivBackward1>)

# %% [markdown]
# ## Función de entrenamiento
# - Ahora se trata de hacer una función que haga una iteración simple de entrenamiento (epoch) sobre una entrada
#     -  Se recoge cada uno de los grupos de entrada
#         1. Separamos entre datos de entrada y salida deseada
#         2. Se pone los gradientes a cero
#         3. Se calcula la salida
#         4. Se calcula el error en la salida en las capas intermedias
#         5. Modificamos pesos
#         6. Capturamos información para informes

# %%
def train_one_epoch(epoch_index, tb_writer):
    running_loss = 0.
    last_loss = 0.
    # usamos enumerate para saber en que batch imos
    for i, data in enumerate(train_ldr):
        # Every data instance is an input + label pair
        inputs, labels = data
        # Zero your gradients for every batch!
        optimizer.zero_grad()
        # Make predictions for this batch
        outputs = model(inputs)
        # Compute the loss and its gradients
        loss = loss_fn(outputs, labels)
        loss.backward()
        # Adjust learning weights
        optimizer.step()
        # Gather data and report
        running_loss += loss.item()
        if i % 10 == 9:
            last_loss = running_loss / 10 # loss per batch
            print('  batch {} loss: {}'.format(i + 1, last_loss))
            running_loss = 0.
    return last_loss

# %% [markdown]
# - El entrenamiento consiste en ir pasando la función anterior unas cuantas veces en bucle y validando el entrenamiento con el test
# - El test se puede hacer al final o durante el propio entrenamiento (depende la información que queramos ver)

# %%
EPOCHS = 100
loss_list     = torch.zeros((EPOCHS,))
accuracy_list = torch.zeros((EPOCHS,))
writer = SummaryWriter('runs/experimento_iris')
for epoch in range(EPOCHS):
    print('EPOCH {}:'.format(epoch + 1))

    # Poñemos o modelo en modo entrenamento
    model.train(True)
    avg_loss = train_one_epoch(epoch, writer)
    loss_list[epoch] = avg_loss
    # Non se precisan os gradientes para o test
    model.train(False)
    running_vloss = 0.0
    for i, vdata in enumerate(validation_loader):
        vinputs, vlabels = vdata
        voutputs = model(vinputs)
        vloss = loss_fn(voutputs, vlabels)

        print(f"Forma de voutputs: {voutputs.shape}")
        print(f"Forma de vlabels: {vlabels.shape}")

        # TODO: aperez: En clasificación, dim=1 nos da la clase ganadora para cada elemento del lote.
        correct = (torch.argmax(voutputs, dim=1) == torch.argmax(vlabels, dim=1)).type(torch.FloatTensor)
        accuracy_list[epoch] += correct.sum()
        running_vloss += vloss

    avg_vloss = running_vloss / (i + 1)
    accuracy_list[epoch] = (accuracy_list[epoch] / int(lonxitudeDataset*0.2)) * 100
    
    print('EPOCH {}: LOSS train {:.4f} valid {:.4f} | Acc: {:.2f}%'.format(
        epoch + 1, avg_loss, avg_vloss, accuracy_list[epoch]
    ))
# Out:
# EPOCH 1:
#   batch 10 loss: 1.0890171527862549
#   batch 20 loss: 1.0572491407394409
#   batch 30 loss: 1.0053186118602753
#   batch 40 loss: 0.9658229649066925
#   batch 50 loss: 0.9168479859828949
#   batch 60 loss: 0.9754908680915833
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 1: LOSS train 0.9755 valid 0.8307 | Acc: 86.67%
# EPOCH 2:
#   batch 10 loss: 0.9353624880313873
#   batch 20 loss: 0.7997105836868286
#   batch 30 loss: 0.7797468841075897
#   batch 40 loss: 0.8693726778030395
#   batch 50 loss: 0.7469315588474273
#   batch 60 loss: 0.703680020570755
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 2: LOSS train 0.7037 valid 0.7094 | Acc: 86.67%
# EPOCH 3:
#   batch 10 loss: 0.7427719533443451
#   batch 20 loss: 0.7526406466960907
#   batch 30 loss: 0.7160280406475067
#   batch 40 loss: 0.712365698814392
#   batch 50 loss: 0.6485553801059722
#   batch 60 loss: 0.7328059375286102
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 3: LOSS train 0.7328 valid 0.6812 | Acc: 93.33%
# EPOCH 4:
#   batch 10 loss: 0.6716963291168213
#   batch 20 loss: 0.749361801147461
#   batch 30 loss: 0.6308117568492889
#   batch 40 loss: 0.6537535130977631
#   batch 50 loss: 0.6507166504859925
#   batch 60 loss: 0.6325380027294158
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 4: LOSS train 0.6325 valid 0.6496 | Acc: 90.00%
# EPOCH 5:
#   batch 10 loss: 0.6225021362304688
#   batch 20 loss: 0.6564449369907379
#   batch 30 loss: 0.6718593120574952
#   batch 40 loss: 0.6296441912651062
#   batch 50 loss: 0.603240692615509
#   batch 60 loss: 0.6156993567943573
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 5: LOSS train 0.6157 valid 0.6345 | Acc: 93.33%
# EPOCH 6:
#   batch 10 loss: 0.6216816425323486
#   batch 20 loss: 0.6282636761665344
#   batch 30 loss: 0.5889023780822754
#   batch 40 loss: 0.5981206178665162
#   batch 50 loss: 0.5966795027256012
#   batch 60 loss: 0.670225340127945
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 6: LOSS train 0.6702 valid 0.6220 | Acc: 93.33%
# EPOCH 7:
#   batch 10 loss: 0.6003441870212555
#   batch 20 loss: 0.6045068204402924
#   batch 30 loss: 0.600696724653244
#   batch 40 loss: 0.6192177712917328
#   batch 50 loss: 0.6069025278091431
#   batch 60 loss: 0.5806040406227112
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 7: LOSS train 0.5806 valid 0.6133 | Acc: 96.67%
# EPOCH 8:
#   batch 10 loss: 0.5885104298591614
#   batch 20 loss: 0.6299652099609375
#   batch 30 loss: 0.5963743090629577
#   batch 40 loss: 0.6133044958114624
#   batch 50 loss: 0.5669731736183167
#   batch 60 loss: 0.6042836785316468
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 8: LOSS train 0.6043 valid 0.6137 | Acc: 93.33%
# EPOCH 9:
#   batch 10 loss: 0.5668087720870971
#   batch 20 loss: 0.6083384692668915
#   batch 30 loss: 0.6054141283035278
#   batch 40 loss: 0.5791634023189545
#   batch 50 loss: 0.57425177693367
#   batch 60 loss: 0.6138253271579742
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 9: LOSS train 0.6138 valid 0.6069 | Acc: 96.67%
# EPOCH 10:
#   batch 10 loss: 0.5784348547458649
#   batch 20 loss: 0.5626570522785187
#   batch 30 loss: 0.6133563637733459
#   batch 40 loss: 0.5984637975692749
#   batch 50 loss: 0.5629005432128906
#   batch 60 loss: 0.6008011758327484
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 10: LOSS train 0.6008 valid 0.6130 | Acc: 93.33%
# EPOCH 11:
#   batch 10 loss: 0.5787410736083984
#   batch 20 loss: 0.5640413224697113
#   batch 30 loss: 0.5955143511295319
#   batch 40 loss: 0.5968238115310669
#   batch 50 loss: 0.5979025840759278
#   batch 60 loss: 0.575698459148407
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 11: LOSS train 0.5757 valid 0.6120 | Acc: 93.33%
# EPOCH 12:
#   batch 10 loss: 0.5700276076793671
#   batch 20 loss: 0.5706808626651764
#   batch 30 loss: 0.570330148935318
#   batch 40 loss: 0.6119518339633941
#   batch 50 loss: 0.6067878007888794
#   batch 60 loss: 0.5619223058223725
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 12: LOSS train 0.5619 valid 0.6042 | Acc: 96.67%
# EPOCH 13:
#   batch 10 loss: 0.5779340028762817
#   batch 20 loss: 0.5685843884944916
#   batch 30 loss: 0.5775673151016235
#   batch 40 loss: 0.5844866394996643
#   batch 50 loss: 0.5958903670310974
#   batch 60 loss: 0.5546166300773621
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 13: LOSS train 0.5546 valid 0.5992 | Acc: 96.67%
# EPOCH 14:
#   batch 10 loss: 0.599055802822113
#   batch 20 loss: 0.6304507434368134
#   batch 30 loss: 0.5684368371963501
#   batch 40 loss: 0.5653104543685913
#   batch 50 loss: 0.5638092279434204
#   batch 60 loss: 0.5627958655357361
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 14: LOSS train 0.5628 valid 0.6007 | Acc: 96.67%
# EPOCH 15:
#   batch 10 loss: 0.5623273134231568
#   batch 20 loss: 0.5673250913619995
#   batch 30 loss: 0.6331100761890411
#   batch 40 loss: 0.5640345811843872
#   batch 50 loss: 0.5733253657817841
#   batch 60 loss: 0.5641845405101776
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 15: LOSS train 0.5642 valid 0.6102 | Acc: 93.33%
# EPOCH 16:
#   batch 10 loss: 0.5762402236461639
#   batch 20 loss: 0.5747023105621338
#   batch 30 loss: 0.5865171372890472
#   batch 40 loss: 0.593128752708435
#   batch 50 loss: 0.5553181827068329
#   batch 60 loss: 0.5535569489002228
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 16: LOSS train 0.5536 valid 0.6079 | Acc: 93.33%
# EPOCH 17:
#   batch 10 loss: 0.5720478892326355
#   batch 20 loss: 0.5790581464767456
#   batch 30 loss: 0.5567909955978394
#   batch 40 loss: 0.5868177711963654
#   batch 50 loss: 0.5911102175712586
#   batch 60 loss: 0.5531016409397125
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 17: LOSS train 0.5531 valid 0.6124 | Acc: 93.33%
# EPOCH 18:
#   batch 10 loss: 0.5684414088726044
#   batch 20 loss: 0.5691838979721069
#   batch 30 loss: 0.5722081184387207
#   batch 40 loss: 0.5532471716403962
#   batch 50 loss: 0.5970158696174621
#   batch 60 loss: 0.5727747499942779
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 18: LOSS train 0.5728 valid 0.6106 | Acc: 93.33%
# EPOCH 19:
#   batch 10 loss: 0.5754652976989746
#   batch 20 loss: 0.571877533197403
#   batch 30 loss: 0.5616635024547577
#   batch 40 loss: 0.5608351051807403
#   batch 50 loss: 0.5656530916690826
#   batch 60 loss: 0.5787226855754852
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 19: LOSS train 0.5787 valid 0.5993 | Acc: 96.67%
# EPOCH 20:
#   batch 10 loss: 0.5549804449081421
#   batch 20 loss: 0.5616754233837128
#   batch 30 loss: 0.6217694699764251
#   batch 40 loss: 0.5591810584068299
#   batch 50 loss: 0.6024086475372314
#   batch 60 loss: 0.5544450223445893
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 20: LOSS train 0.5544 valid 0.6160 | Acc: 93.33%
# EPOCH 21:
#   batch 10 loss: 0.5791015207767487
#   batch 20 loss: 0.5555835425853729
#   batch 30 loss: 0.5881485521793366
#   batch 40 loss: 0.5824437141418457
#   batch 50 loss: 0.5534897804260254
#   batch 60 loss: 0.5635818064212799
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 21: LOSS train 0.5636 valid 0.6318 | Acc: 93.33%
# EPOCH 22:
#   batch 10 loss: 0.5542461037635803
#   batch 20 loss: 0.5934965968132019
#   batch 30 loss: 0.5556606769561767
#   batch 40 loss: 0.5580110609531402
#   batch 50 loss: 0.6018626272678376
#   batch 60 loss: 0.5540895223617553
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 22: LOSS train 0.5541 valid 0.6302 | Acc: 93.33%
# EPOCH 23:
#   batch 10 loss: 0.5906499564647675
#   batch 20 loss: 0.5757395565509796
#   batch 30 loss: 0.5547555148601532
#   batch 40 loss: 0.5617954313755036
#   batch 50 loss: 0.5521214544773102
#   batch 60 loss: 0.57162926197052
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 23: LOSS train 0.5716 valid 0.6121 | Acc: 93.33%
# EPOCH 24:
#   batch 10 loss: 0.5933741152286529
#   batch 20 loss: 0.5518809735774994
#   batch 30 loss: 0.5589026272296905
#   batch 40 loss: 0.5717510461807251
#   batch 50 loss: 0.5526914775371552
#   batch 60 loss: 0.5637557029724121
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 24: LOSS train 0.5638 valid 0.6178 | Acc: 93.33%
# EPOCH 25:
#   batch 10 loss: 0.561177545785904
#   batch 20 loss: 0.5862698256969452
#   batch 30 loss: 0.5532447457313537
#   batch 40 loss: 0.5533789932727814
#   batch 50 loss: 0.5590312898159027
#   batch 60 loss: 0.5876209139823914
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 25: LOSS train 0.5876 valid 0.6199 | Acc: 93.33%
# EPOCH 26:
#   batch 10 loss: 0.5644886553287506
#   batch 20 loss: 0.5773313879966736
#   batch 30 loss: 0.5620692729949951
#   batch 40 loss: 0.5802674412727356
#   batch 50 loss: 0.5572612643241882
#   batch 60 loss: 0.5563483476638794
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 26: LOSS train 0.5563 valid 0.6167 | Acc: 93.33%
# EPOCH 27:
#   batch 10 loss: 0.5634497404098511
#   batch 20 loss: 0.5574117004871368
#   batch 30 loss: 0.5536681652069092
#   batch 40 loss: 0.5718817353248596
#   batch 50 loss: 0.55227010846138
#   batch 60 loss: 0.5905245304107666
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 27: LOSS train 0.5905 valid 0.6018 | Acc: 96.67%
# EPOCH 28:
#   batch 10 loss: 0.5540346682071686
#   batch 20 loss: 0.5684678196907044
#   batch 30 loss: 0.5568693161010743
#   batch 40 loss: 0.5676187694072723
#   batch 50 loss: 0.5729649603366852
#   batch 60 loss: 0.555589246749878
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 28: LOSS train 0.5556 valid 0.6038 | Acc: 96.67%
# EPOCH 29:
#   batch 10 loss: 0.5539103746414185
#   batch 20 loss: 0.563749349117279
#   batch 30 loss: 0.554458099603653
#   batch 40 loss: 0.5524921894073487
#   batch 50 loss: 0.5877437949180603
#   batch 60 loss: 0.596714323759079
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 29: LOSS train 0.5967 valid 0.6297 | Acc: 93.33%
# EPOCH 30:
#   batch 10 loss: 0.5540756464004517
#   batch 20 loss: 0.5681971371173858
#   batch 30 loss: 0.5526801824569703
#   batch 40 loss: 0.5711109340190887
#   batch 50 loss: 0.5722544431686402
#   batch 60 loss: 0.5586110591888428
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 30: LOSS train 0.5586 valid 0.6184 | Acc: 93.33%
# EPOCH 31:
#   batch 10 loss: 0.568662577867508
#   batch 20 loss: 0.5658191323280335
#   batch 30 loss: 0.5562448143959046
#   batch 40 loss: 0.5560211062431335
#   batch 50 loss: 0.5584469437599182
#   batch 60 loss: 0.5567252814769745
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 31: LOSS train 0.5567 valid 0.6219 | Acc: 93.33%
# EPOCH 32:
#   batch 10 loss: 0.5544653594493866
#   batch 20 loss: 0.5562784731388092
#   batch 30 loss: 0.5566326558589936
#   batch 40 loss: 0.5666587948799133
#   batch 50 loss: 0.5519332468509675
#   batch 60 loss: 0.5775318920612336
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 32: LOSS train 0.5775 valid 0.6200 | Acc: 93.33%
# EPOCH 33:
#   batch 10 loss: 0.5584994316101074
#   batch 20 loss: 0.554790872335434
#   batch 30 loss: 0.5527076959609986
#   batch 40 loss: 0.553241366147995
#   batch 50 loss: 0.5658190369606018
#   batch 60 loss: 0.5779288113117218
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 33: LOSS train 0.5779 valid 0.6257 | Acc: 93.33%
# EPOCH 34:
#   batch 10 loss: 0.5659863293170929
#   batch 20 loss: 0.5539996087551117
#   batch 30 loss: 0.5560132920742035
#   batch 40 loss: 0.5522916138172149
#   batch 50 loss: 0.5595874905586242
#   batch 60 loss: 0.5658898234367371
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 34: LOSS train 0.5659 valid 0.6111 | Acc: 93.33%
# EPOCH 35:
#   batch 10 loss: 0.5524421036243439
#   batch 20 loss: 0.5642210960388183
#   batch 30 loss: 0.55240877866745
#   batch 40 loss: 0.5603797614574433
#   batch 50 loss: 0.5671349108219147
#   batch 60 loss: 0.5566595196723938
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 35: LOSS train 0.5567 valid 0.6168 | Acc: 93.33%
# EPOCH 36:
#   batch 10 loss: 0.5533577799797058
#   batch 20 loss: 0.5576075494289399
#   batch 30 loss: 0.5617952406406402
#   batch 40 loss: 0.5532540380954742
#   batch 50 loss: 0.5517729640007019
#   batch 60 loss: 0.5773272812366486
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 36: LOSS train 0.5773 valid 0.6168 | Acc: 93.33%
# EPOCH 37:
#   batch 10 loss: 0.5529303073883056
#   batch 20 loss: 0.5520275294780731
#   batch 30 loss: 0.5763907134532928
#   batch 40 loss: 0.5634689807891846
#   batch 50 loss: 0.5611112654209137
#   batch 60 loss: 0.5540390014648438
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 37: LOSS train 0.5540 valid 0.6244 | Acc: 93.33%
# EPOCH 38:
#   batch 10 loss: 0.5520698368549347
#   batch 20 loss: 0.5530344426631928
#   batch 30 loss: 0.5671246409416199
#   batch 40 loss: 0.5585168302059174
#   batch 50 loss: 0.5515634596347809
#   batch 60 loss: 0.5650915980339051
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 38: LOSS train 0.5651 valid 0.6232 | Acc: 93.33%
# EPOCH 39:
#   batch 10 loss: 0.5532079577445984
#   batch 20 loss: 0.565173602104187
#   batch 30 loss: 0.5518728375434876
#   batch 40 loss: 0.5547056555747986
#   batch 50 loss: 0.5644979476928711
#   batch 60 loss: 0.5587512612342834
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 39: LOSS train 0.5588 valid 0.6071 | Acc: 93.33%
# EPOCH 40:
#   batch 10 loss: 0.5522239983081818
#   batch 20 loss: 0.5518889129161835
#   batch 30 loss: 0.5673411250114441
#   batch 40 loss: 0.5528954982757568
#   batch 50 loss: 0.5560094118118286
#   batch 60 loss: 0.5603655040264129
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 40: LOSS train 0.5604 valid 0.6248 | Acc: 93.33%
# EPOCH 41:
#   batch 10 loss: 0.5545975029468536
#   batch 20 loss: 0.5760990142822265
#   batch 30 loss: 0.5535848498344421
#   batch 40 loss: 0.556089061498642
#   batch 50 loss: 0.5520177602767944
#   batch 60 loss: 0.552137041091919
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 41: LOSS train 0.5521 valid 0.6210 | Acc: 93.33%
# EPOCH 42:
#   batch 10 loss: 0.5521028280258179
#   batch 20 loss: 0.5543135106563568
#   batch 30 loss: 0.5534567654132843
#   batch 40 loss: 0.5538643896579742
#   batch 50 loss: 0.5742935061454773
#   batch 60 loss: 0.5523317098617554
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 42: LOSS train 0.5523 valid 0.6309 | Acc: 93.33%
# EPOCH 43:
#   batch 10 loss: 0.5696600139141083
#   batch 20 loss: 0.5526158809661865
#   batch 30 loss: 0.5654826641082764
#   batch 40 loss: 0.5538360059261322
#   batch 50 loss: 0.5543468475341797
#   batch 60 loss: 0.5566486358642578
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 43: LOSS train 0.5566 valid 0.6342 | Acc: 93.33%
# EPOCH 44:
#   batch 10 loss: 0.5551428675651551
#   batch 20 loss: 0.5586835086345673
#   batch 30 loss: 0.5519412338733674
#   batch 40 loss: 0.552430784702301
#   batch 50 loss: 0.573147076368332
#   batch 60 loss: 0.5556593298912048
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 44: LOSS train 0.5557 valid 0.6351 | Acc: 93.33%
# EPOCH 45:
#   batch 10 loss: 0.5525270164012909
#   batch 20 loss: 0.5518744587898254
#   batch 30 loss: 0.5567891895771027
#   batch 40 loss: 0.5551210701465606
#   batch 50 loss: 0.5599021911621094
#   batch 60 loss: 0.557734364271164
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 45: LOSS train 0.5577 valid 0.6200 | Acc: 93.33%
# EPOCH 46:
#   batch 10 loss: 0.5567076206207275
#   batch 20 loss: 0.5517731368541717
#   batch 30 loss: 0.551661628484726
#   batch 40 loss: 0.5567479014396668
#   batch 50 loss: 0.5609942495822906
#   batch 60 loss: 0.5550236999988556
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 46: LOSS train 0.5550 valid 0.6100 | Acc: 93.33%
# EPOCH 47:
#   batch 10 loss: 0.5522718966007233
#   batch 20 loss: 0.5541102051734924
#   batch 30 loss: 0.5585029482841491
#   batch 40 loss: 0.5579966127872467
#   batch 50 loss: 0.5533863782882691
#   batch 60 loss: 0.566898775100708
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 47: LOSS train 0.5669 valid 0.6216 | Acc: 93.33%
# EPOCH 48:
#   batch 10 loss: 0.5525759398937226
#   batch 20 loss: 0.5517998337745667
#   batch 30 loss: 0.5728745520114898
#   batch 40 loss: 0.5526438474655151
#   batch 50 loss: 0.5522104740142822
#   batch 60 loss: 0.5639908611774445
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 48: LOSS train 0.5640 valid 0.6287 | Acc: 93.33%
# EPOCH 49:
#   batch 10 loss: 0.5516711652278901
#   batch 20 loss: 0.5527069807052613
#   batch 30 loss: 0.5548959195613861
#   batch 40 loss: 0.5547986030578613
#   batch 50 loss: 0.5617574095726013
#   batch 60 loss: 0.5521575450897217
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 49: LOSS train 0.5522 valid 0.6191 | Acc: 93.33%
# EPOCH 50:
#   batch 10 loss: 0.5517166018486023
#   batch 20 loss: 0.5591053545475007
#   batch 30 loss: 0.556128716468811
#   batch 40 loss: 0.5533925831317902
#   batch 50 loss: 0.5518287062644959
#   batch 60 loss: 0.5581030011177063
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 50: LOSS train 0.5581 valid 0.6169 | Acc: 93.33%
# EPOCH 51:
#   batch 10 loss: 0.553664892911911
#   batch 20 loss: 0.5517151236534119
#   batch 30 loss: 0.562449437379837
#   batch 40 loss: 0.5523052394390107
#   batch 50 loss: 0.5565275073051452
#   batch 60 loss: 0.5518185555934906
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 51: LOSS train 0.5518 valid 0.6288 | Acc: 93.33%
# EPOCH 52:
#   batch 10 loss: 0.5535588264465332
#   batch 20 loss: 0.5628975808620453
#   batch 30 loss: 0.5521551370620728
#   batch 40 loss: 0.5523245632648468
#   batch 50 loss: 0.5520662784576416
#   batch 60 loss: 0.5652713358402253
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 52: LOSS train 0.5653 valid 0.6300 | Acc: 93.33%
# EPOCH 53:
#   batch 10 loss: 0.5548561155796051
#   batch 20 loss: 0.5540946185588836
#   batch 30 loss: 0.5515270411968232
#   batch 40 loss: 0.5550268292427063
#   batch 50 loss: 0.553194797039032
#   batch 60 loss: 0.5576730728149414
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 53: LOSS train 0.5577 valid 0.6206 | Acc: 93.33%
# EPOCH 54:
#   batch 10 loss: 0.5516791999340057
#   batch 20 loss: 0.5518559098243714
#   batch 30 loss: 0.5515260100364685
#   batch 40 loss: 0.5539961755275726
#   batch 50 loss: 0.5517089545726777
#   batch 60 loss: 0.564490681886673
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 54: LOSS train 0.5645 valid 0.6252 | Acc: 93.33%
# EPOCH 55:
#   batch 10 loss: 0.5589311480522156
#   batch 20 loss: 0.5527366816997528
#   batch 30 loss: 0.5522412657737732
#   batch 40 loss: 0.5517799437046051
#   batch 50 loss: 0.5519279479980469
#   batch 60 loss: 0.5594700455665589
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# ...
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 82: LOSS train 0.5522 valid 0.6203 | Acc: 93.33%
# EPOCH 83:
#   batch 10 loss: 0.5514677941799164
#   batch 20 loss: 0.5520599782466888
#   batch 30 loss: 0.5515055894851685
#   batch 40 loss: 0.5536933064460754
#   batch 50 loss: 0.5515417456626892
#   batch 60 loss: 0.5527487337589264
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 83: LOSS train 0.5527 valid 0.6203 | Acc: 93.33%
# EPOCH 84:
#   batch 10 loss: 0.5519674897193909
#   batch 20 loss: 0.5519115090370178
#   batch 30 loss: 0.5514713943004608
#   batch 40 loss: 0.5534608423709869
#   batch 50 loss: 0.5515488922595978
#   batch 60 loss: 0.5518261015415191
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 84: LOSS train 0.5518 valid 0.6205 | Acc: 93.33%
# EPOCH 85:
#   batch 10 loss: 0.5517037987709046
#   batch 20 loss: 0.5524686813354492
#   batch 30 loss: 0.5518499851226807
#   batch 40 loss: 0.5524688720703125
#   batch 50 loss: 0.5514963269233704
#   batch 60 loss: 0.5519986629486084
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 85: LOSS train 0.5520 valid 0.6206 | Acc: 93.33%
# EPOCH 86:
#   batch 10 loss: 0.5516325950622558
#   batch 20 loss: 0.5516287803649902
#   batch 30 loss: 0.5520092248916626
#   batch 40 loss: 0.5532748162746429
#   batch 50 loss: 0.551477563381195
#   batch 60 loss: 0.5517756998538971
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 86: LOSS train 0.5518 valid 0.6208 | Acc: 93.33%
# EPOCH 87:
#   batch 10 loss: 0.552481186389923
#   batch 20 loss: 0.5522984862327576
#   batch 30 loss: 0.5524229586124421
#   batch 40 loss: 0.5520079910755158
#   batch 50 loss: 0.5514941096305848
#   batch 60 loss: 0.5514524281024933
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 87: LOSS train 0.5515 valid 0.6205 | Acc: 93.33%
# EPOCH 88:
#   batch 10 loss: 0.5516398012638092
#   batch 20 loss: 0.5514949858188629
#   batch 30 loss: 0.551643180847168
#   batch 40 loss: 0.5524237871170044
#   batch 50 loss: 0.5524012267589569
#   batch 60 loss: 0.5519892036914825
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 88: LOSS train 0.5520 valid 0.6206 | Acc: 93.33%
# EPOCH 89:
#   batch 10 loss: 0.5514762222766876
#   batch 20 loss: 0.5516512453556061
#   batch 30 loss: 0.551502525806427
#   batch 40 loss: 0.552315068244934
#   batch 50 loss: 0.5518569827079773
#   batch 60 loss: 0.5530198037624359
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 89: LOSS train 0.5530 valid 0.6210 | Acc: 93.33%
# EPOCH 90:
#   batch 10 loss: 0.5514667451381683
#   batch 20 loss: 0.5522893369197845
#   batch 30 loss: 0.5516460418701172
#   batch 40 loss: 0.5514719605445861
#   batch 50 loss: 0.5526926457881928
#   batch 60 loss: 0.5523383140563964
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 90: LOSS train 0.5523 valid 0.6207 | Acc: 93.33%
# EPOCH 91:
#   batch 10 loss: 0.5521703898906708
#   batch 20 loss: 0.5515964806079865
#   batch 30 loss: 0.5518213272094726
#   batch 40 loss: 0.5517001569271087
#   batch 50 loss: 0.5516716718673706
#   batch 60 loss: 0.552365779876709
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 91: LOSS train 0.5524 valid 0.6206 | Acc: 93.33%
# EPOCH 92:
#   batch 10 loss: 0.552121764421463
#   batch 20 loss: 0.5525472104549408
#   batch 30 loss: 0.5518094420433044
#   batch 40 loss: 0.5515658140182496
#   batch 50 loss: 0.5515750229358674
#   batch 60 loss: 0.5515183329582214
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 92: LOSS train 0.5515 valid 0.6203 | Acc: 93.33%
# EPOCH 93:
#   batch 10 loss: 0.551475715637207
#   batch 20 loss: 0.5522000014781951
#   batch 30 loss: 0.5527417659759521
#   batch 40 loss: 0.5515349090099335
#   batch 50 loss: 0.5520285427570343
#   batch 60 loss: 0.5514607667922974
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 93: LOSS train 0.5515 valid 0.6204 | Acc: 93.33%
# EPOCH 94:
#   batch 10 loss: 0.5518296957015991
#   batch 20 loss: 0.5525298833847045
#   batch 30 loss: 0.5514629483222961
#   batch 40 loss: 0.5514888525009155
#   batch 50 loss: 0.5520679593086243
#   batch 60 loss: 0.5518109619617462
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 94: LOSS train 0.5518 valid 0.6202 | Acc: 93.33%
# EPOCH 95:
#   batch 10 loss: 0.5514602839946747
#   batch 20 loss: 0.5521392524242401
#   batch 30 loss: 0.5514684200286866
#   batch 40 loss: 0.5524235785007476
#   batch 50 loss: 0.5516495764255523
#   batch 60 loss: 0.5518313527107239
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 95: LOSS train 0.5518 valid 0.6201 | Acc: 93.33%
# EPOCH 96:
#   batch 10 loss: 0.5516620218753815
#   batch 20 loss: 0.5522235751152038
#   batch 30 loss: 0.551467913389206
#   batch 40 loss: 0.5523293435573577
#   batch 50 loss: 0.5519519031047821
#   batch 60 loss: 0.5516025483608246
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 96: LOSS train 0.5516 valid 0.6202 | Acc: 93.33%
# EPOCH 97:
#   batch 10 loss: 0.5514790832996368
#   batch 20 loss: 0.5514465749263764
#   batch 30 loss: 0.5516505539417267
#   batch 40 loss: 0.5516039490699768
#   batch 50 loss: 0.5521190285682678
#   batch 60 loss: 0.5524869620800018
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 97: LOSS train 0.5525 valid 0.6200 | Acc: 93.33%
# EPOCH 98:
#   batch 10 loss: 0.5516342222690582
#   batch 20 loss: 0.5514589726924897
#   batch 30 loss: 0.5519417285919189
#   batch 40 loss: 0.5516696095466613
#   batch 50 loss: 0.5519472420215606
#   batch 60 loss: 0.5521177470684051
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 98: LOSS train 0.5521 valid 0.6200 | Acc: 93.33%
# EPOCH 99:
#   batch 10 loss: 0.5515531539916992
#   batch 20 loss: 0.551497894525528
#   batch 30 loss: 0.5519192218780518
#   batch 40 loss: 0.5514653265476227
#   batch 50 loss: 0.5514506280422211
#   batch 60 loss: 0.552666312456131
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 99: LOSS train 0.5527 valid 0.6198 | Acc: 93.33%
# EPOCH 100:
#   batch 10 loss: 0.5514504551887512
#   batch 20 loss: 0.5521681249141693
#   batch 30 loss: 0.5518061280250549
#   batch 40 loss: 0.5518004775047303
#   batch 50 loss: 0.551915442943573
#   batch 60 loss: 0.5515167415142059
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 100: LOSS train 0.5515 valid 0.6200 | Acc: 93.33%

# %% [markdown]
# ## Mostrar alguna gráfica

# %%
plt.style.use('ggplot')
fig, (ax1, ax2) = plt.subplots(2, figsize=(12, 6), sharex=True)

ax1.plot(accuracy_list)
ax1.set_ylabel("validation accuracy")
ax2.plot(loss_list)
ax2.set_ylabel("validation loss")
ax2.set_xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# Gráfica de arriba:
# - La línea empieza abajo, cerca del 83%. Esto significa que, nada más empezar a entrenar, la red ya fue capaz de adivinar correctamente el 83% de las flores (unas 25 de 30)
# - Casi inmediatamente, la línea sube y se queda plana en la parte superior, alrededor del 96.6%. Esto te indica que tu modelo alcanzó su máximo aprendizaje muy rápido y se pasó casi todas las 100 épocas acertando 29 de las 30 flores de validación de forma constante.
# - Hay unas cuantas caídas en forma de "V" que bajan hasta el 93.3% aproximadamente. Son simplemente momentos puntuales donde la red tuvo una ligera duda matemática y falló una flor más (acertando 28 de 30). Es un comportamiento totalmente normal.
#
# Gráfica de abajo:
# - La pérdida (loss) mide cuánto se equivoca la red. Cuanto más bajo sea el número, mejor.
# - Al principio (época 0), el error es alto (casi 1.0) porque la red no sabe nada y está adivinando al azar. En las primeras 10 épocas, la curva cae en picado, lo que significa que la red está aprendiendo rapidísimo a identificar los patrones de las flores.
# - A partir de la época 40 aproximadamente, la línea se vuelve casi plana. Esto indica que el modelo ha convergido: ya ha aprendido todo lo que podía de esos datos y seguir entrenando más épocas apenas mejora el resultado.
