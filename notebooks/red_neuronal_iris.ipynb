# %% [markdown]
# # Tarea 69 - Iris Dataset
# Implementa usando PyTorch y siguiendo la domcumentación un clasificador para el dataset Iris.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

import torch
from torch.utils.data import Dataset

import torch.nn.functional as F
import torch.nn as nn
from torch.utils.data import random_split
from torch.utils.tensorboard import SummaryWriter

# %% [markdown]
# ## Pasos previos
# 1. Cargar o dataset
# 2. Esudiarlo: Ver algún dato, pintar alguna gráfica
# 3. Tranformación de datos

# %% [markdown]
# ### Importar dataset Iris

# %%
irisDataset = pd.read_csv("../data/iris/iris.data", #TODO: aperez: Poner dos puntos para que salga de notebooks y entre en data
                          names=["sepallength","sepalwidth",
                                 "petallength","petalwidth","class"])

# %% [markdown]
# ### Estudio dataset. Datos, mostrar gráficas...

# %%
irisDataset.head(4)
# Out:
#    sepallength  sepalwidth  petallength  petalwidth        class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa

# %%
plt.style.use('ggplot')
nomeClases = irisDataset["class"].unique()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for target, target_name in enumerate(nomeClases):
    X_plot = irisDataset[irisDataset["class"] == target_name]
    ax1.plot(X_plot["sepallength"], X_plot["sepalwidth"], 
             linestyle='none', 
             marker='o', 
             label=target_name)
ax1.set_xlabel("sepallength")
ax1.set_ylabel("sepalwidth")
ax1.axis('equal')
ax1.legend()

# %% [markdown]
# ### Trasformación de Datos

# %% [markdown]
# Para trabajar bien con los datos de una red de neuronas, tenenmos que hacer alguna que otra transformación en los datos de entrada
# - No podemos trabajar con entradas categóricas (class)
# - Los valores de entrada están mejor con media 0 y desviación típica 1
# Se puede hacer una clase que haga transformación del tipo de otro frameworks

# %%
class StandardScaler:

    def __init__(self, mean=None, std=None, epsilon=1e-7):
        """Standard Scaler.
        The class can be used to normalize PyTorch Tensors using native functions. The module does not expect the
        tensors to be of any specific shape; as long as the features are the last dimension in the tensor, the module
        will work fine.
        :param mean: The mean of the features. The property will be set after a call to fit.
        :param std: The standard deviation of the features. The property will be set after a call to fit.
        :param epsilon: Used to avoid a Division-By-Zero exception.
        """
        self.mean = mean
        self.std = std
        self.epsilon = epsilon
    def fit(self, values):
        dims = list(range(values.dim() - 1))
        self.mean = torch.mean(values, dim=dims)
        self.std = torch.std(values, dim=dims)
    def transform(self, values):
        return (values - self.mean) / (self.std + self.epsilon)

    def fit_transform(self, values):
        self.fit(values)
        return self.transform(values)

    def __repr__(self):
        return f"mean: {self.mean}, std:{self.std}, epsilon:{self.epsilon}"

# %% [markdown]
# ### Datasets en PyTorch

# %% [markdown]
# Para evitar que el código de lectura de datos se vuelva caótico y difícil de mantener, PyTorch centraliza este proceso usando Datasets y DataLoaders.
# - **El rol del Dataset**: Es el objeto responsable de almacenar, leer y adaptar la información. PyTorch no hace distinción entre sus Datasets predefinidos y los que tú decidas crear desde cero; ambos se tratan igual en el ecosistema.
# - **Creación de un Dataset personalizado**: Para hacer uno propio, debes crear una clase en Python que herede de torch.utils.data.Dataset.
# Esta clase personalizada debe implementar obligatoriamente tres métodos fundamentales:
# 1. __ init__: Es el constructor. Aquí debes leer los datos originales y dejarlos preparados en memoria.
# 2. __ len__: Debe devolver el número total de patrones o muestras que tiene tu conjunto de datos.
# 3. __ getitem__: Es el encargado de extraer y devolver un patrón o muestra individual cuando se le pide.

# %%
class IrisDataset(Dataset):
  def __init__(self, src_file, root_dir, transform=None):
    irisDataset = pd.read_csv(src_file, names=["sepallength","sepalwidth","petallength","petalwidth","class"])
    X = irisDataset[irisDataset.columns.intersection(["sepallength","sepalwidth","petallength","petalwidth"])]
    Y = irisDataset[irisDataset.columns.intersection(["class"])]
    nomeClases = Y["class"].unique()
    conversion = {v: k for k, v in dict(enumerate(nomeClases)).items()}
    YConversion = pd.DataFrame()
    for nome in nomeClases:
      YConversion[nome] = (Y["class"]==nome).apply(lambda x : 1.0 if x else 0.0)
    y_tensor = torch.as_tensor(YConversion.to_numpy()).type(torch.float32)
    df_dict = dict.fromkeys(X.columns, '')
    X.rename(columns = df_dict)
    s1=X.iloc[:,0:4].values
    x_tensor = torch.tensor(s1)
    scaler = StandardScaler()
    scaler.fit(x_tensor)
    XScalada = scaler.fit_transform(x_tensor).type(torch.float32)
    self.data = torch.cat((XScalada,y_tensor),1)
    self.root_dir = root_dir
    self.transform = transform
  def __len__(self):
    return len(self.data)

  def __getitem__(self, idx):
    if torch.is_tensor(idx):
      idx = idx.tolist()
    preds = self.data[idx, 0:4]
    spcs = self.data[idx, 4:]
    sample = (preds, spcs)
    if self.transform:
      sample = self.transform(sample)
    return sample

# %% [markdown]
# ### Carga de datos por IrisDataset

# %% [markdown]
# No viene mal acceder al primer elemento, por ver si algo sale mal

# %%
dataset = IrisDataset("../data/iris/iris.data",".")
display(dataset[0]) # comprobamos que sale algo
# Out:
# (tensor([-0.8977,  1.0286, -1.3368, -1.3086]), tensor([1., 0., 0.]))

# %% [markdown]
# ## División en Train y Test
# - No se puede añadir elementos a untensor después de la creación
# - Pero podemos crear un nuevo tensor que una dos tensor, para eso está la función **cat**

# %%
lonxitudeDataset = len(dataset)
tamTrain =int(lonxitudeDataset*0.8)
tamVal = int(lonxitudeDataset*0.2)

train_set, val_set = random_split(dataset, [tamTrain, tamVal]) # TODO: aperez: Faltaba esta linea para futuros proyectos

print(f"Tam dataset: {lonxitudeDataset} train: {tamTrain} tamVal: {tamVal}")
train_ldr = torch.utils.data.DataLoader(train_set, batch_size=2,
    shuffle=True, drop_last=False)
# TODO: aperez: num_workers=2 -> S.O: Linux o macOS, PyTorch puede crear "clones" (forks) del proceso principal muy fácilmente para que carguen los datos en paralelo
#               En Windowns maneja el multiprocesamiento de forma diferente (usa algo llamado spawn). Al intentar crear estos subprocesos dentro de un Notebook, 
#               Windows se lía intentando recargar todo tu código desde cero, y los trabajadores colapsan. Ponemos a 0!!

# validation_loader =torch.utils.data.DataLoader(val_set, batch_size=4, shuffle=False, num_workers=2)
validation_loader =torch.utils.data.DataLoader(val_set, batch_size=4, shuffle=False, num_workers=0)
# Out:
# Tam dataset: 150 train: 120 tamVal: 30

# %% [markdown]
# ## Creación del Modelo
# - El modelo tiene que derivar de la clase **torch.nn.Module**
# - Deberiamos tener el método __ init__ y el método **forward**
#     - En init hay que definir la estructura del modelo: capas que tiene, tipo de capa, elementos en cada capa
#     - En forward hay que indicar como se hace el cálculo cara delante: a partir de una entrada obtener la salida

# %%
class Model(nn.Module):
    def __init__(self, input_dim):
        super(Model, self).__init__()
        self.layer1 = nn.Linear(input_dim, 50)
        self.layer2 = nn.Linear(50, 50)
        self.layer3 = nn.Linear(in_features=50, out_features=3)
        
    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        x = F.softmax(self.layer3(x), dim=1)
        return x

# %% [markdown]
# - Para las capas usamos *Linear*
#     - El primer parámetro es el tamaño de entrada
#     - El segundo parámetro es la salida
# - Para el cálculo de la salida usamos relu e softmax

# %% [markdown]
# ## Instanciar el Modelo
# - Una vez instanciado el modelo hay:
#     - Instanciarlo
#     - Definir el optimizador
#     - Definir la función de error
# - Para este dataset utilizaremos optimizadores **Adam** y **CrossEntropyLoss**

# %%
model     = Model(4) #TODO: aperez: IMPORTANTE!! Tiene que coincidir con el número de características de entrada (features) que tiene cada patrón
                     # Al ser el datset de Iris , tiene 4 
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn   = nn.CrossEntropyLoss()
display(model)
# Out:
# Model(
#   (layer1): Linear(in_features=4, out_features=50, bias=True)
#   (layer2): Linear(in_features=50, out_features=50, bias=True)
#   (layer3): Linear(in_features=50, out_features=3, bias=True)
# )

# %% [markdown]
# ### Prueba
# No está de más probar que todo en este proceso encaja y hacer una simulación de una iteración de entrenamientoss

# %%
entradaProba,dest = next(iter(train_ldr))
print("Entrada:")
display(entradaProba)
print("Desexada:")
display(dest)
saida = model(entradaProba) # esta é a proba de verdade
print("Saída:")
display(saida)
loss_fn(saida, dest)
# Out:
# Entrada:
# tensor([[ 0.1892, -0.8164,  0.7602,  0.5259],
#         [ 1.7591, -0.3552,  1.4403,  0.7880]])
# Desexada:
# tensor([[0., 1., 0.],
#         [0., 0., 1.]])
# Saída:
# tensor([[0.3233, 0.3463, 0.3304],
#         [0.3054, 0.3624, 0.3321]], grad_fn=<SoftmaxBackward0>)
# tensor(1.0929, grad_fn=<DivBackward1>)

# %% [markdown]
# ## Función de entrenamiento
# - Ahora se trata de hacer una función que haga una iteración simple de entrenamiento (epoch) sobre una entrada
#     -  Se recoge cada uno de los grupos de entrada
#         1. Separamos entre datos de entrada y salida deseada
#         2. Se pone los gradientes a cero
#         3. Se calcula la salida
#         4. Se calcula el error en la salida en las capas intermedias
#         5. Modificamos pesos
#         6. Capturamos información para informes

# %%
def train_one_epoch(epoch_index, tb_writer):
    running_loss = 0.
    last_loss = 0.
    # usamos enumerate para saber en que batch imos
    for i, data in enumerate(train_ldr):
        # Every data instance is an input + label pair
        inputs, labels = data
        # Zero your gradients for every batch!
        optimizer.zero_grad()
        # Make predictions for this batch
        outputs = model(inputs)
        # Compute the loss and its gradients
        loss = loss_fn(outputs, labels)
        loss.backward()
        # Adjust learning weights
        optimizer.step()
        # Gather data and report
        running_loss += loss.item()
        if i % 10 == 9:
            last_loss = running_loss / 10 # loss per batch
            print('  batch {} loss: {}'.format(i + 1, last_loss))
            running_loss = 0.
    return last_loss

# %% [markdown]
# - El entrenamiento consiste en ir pasando la función anterior unas cuantas veces en bucle y validando el entrenamiento con el test
# - El test se puede hacer al final o durante el propio entrenamiento (depende la información que queramos ver)

# %%
EPOCHS = 100
loss_list     = torch.zeros((EPOCHS,))
accuracy_list = torch.zeros((EPOCHS,))
writer = SummaryWriter('runs/experimento_iris')
for epoch in range(EPOCHS):
    print('EPOCH {}:'.format(epoch + 1))

    # Poñemos o modelo en modo entrenamento
    model.train(True)
    avg_loss = train_one_epoch(epoch, writer)
    loss_list[epoch] = avg_loss
    # Non se precisan os gradientes para o test
    model.train(False)
    running_vloss = 0.0
    for i, vdata in enumerate(validation_loader):
        vinputs, vlabels = vdata
        voutputs = model(vinputs)
        vloss = loss_fn(voutputs, vlabels)

        print(f"Forma de voutputs: {voutputs.shape}")
        print(f"Forma de vlabels: {vlabels.shape}")

        # TODO: aperez: En clasificación, dim=1 nos da la clase ganadora para cada elemento del lote.
        correct = (torch.argmax(voutputs, dim=1) == torch.argmax(vlabels, dim=1)).type(torch.FloatTensor)
        accuracy_list[epoch] += correct.sum()
        running_vloss += vloss

    avg_vloss = running_vloss / (i + 1)
    accuracy_list[epoch] = (accuracy_list[epoch] / int(lonxitudeDataset*0.2)) * 100
    
    print('EPOCH {}: LOSS train {:.4f} valid {:.4f} | Acc: {:.2f}%'.format(
        epoch + 1, avg_loss, avg_vloss, accuracy_list[epoch]
    ))
# Out:
# EPOCH 1:
#   batch 10 loss: 1.082813596725464
#   batch 20 loss: 1.0619665026664733
#   batch 30 loss: 1.0325257182121277
#   batch 40 loss: 1.0003983914852141
#   batch 50 loss: 0.976254791021347
#   batch 60 loss: 0.9205036401748657
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 1: LOSS train 0.9205 valid 0.8984 | Acc: 70.00%
# EPOCH 2:
#   batch 10 loss: 0.8684622764587402
#   batch 20 loss: 0.7623220384120941
#   batch 30 loss: 0.8299888134002685
#   batch 40 loss: 0.8093476176261902
#   batch 50 loss: 0.7759349584579468
#   batch 60 loss: 0.8270930051803589
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 2: LOSS train 0.8271 valid 0.7498 | Acc: 73.33%
# EPOCH 3:
#   batch 10 loss: 0.7843732357025146
#   batch 20 loss: 0.7320865571498871
#   batch 30 loss: 0.7294275820255279
#   batch 40 loss: 0.7191471040248871
#   batch 50 loss: 0.6979065775871277
#   batch 60 loss: 0.6689989626407623
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 3: LOSS train 0.6690 valid 0.6982 | Acc: 86.67%
# EPOCH 4:
#   batch 10 loss: 0.6786620140075683
#   batch 20 loss: 0.7554228067398071
#   batch 30 loss: 0.7106088161468506
#   batch 40 loss: 0.5941511213779449
#   batch 50 loss: 0.678797036409378
#   batch 60 loss: 0.6682520806789398
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 4: LOSS train 0.6683 valid 0.6722 | Acc: 90.00%
# EPOCH 5:
#   batch 10 loss: 0.7174427568912506
#   batch 20 loss: 0.6541561126708985
#   batch 30 loss: 0.6720408856868744
#   batch 40 loss: 0.6686244964599609
#   batch 50 loss: 0.6563599705696106
#   batch 60 loss: 0.60228590965271
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 5: LOSS train 0.6023 valid 0.6371 | Acc: 96.67%
# EPOCH 6:
#   batch 10 loss: 0.6075111746788024
#   batch 20 loss: 0.5964065432548523
#   batch 30 loss: 0.6853054881095886
#   batch 40 loss: 0.681578540802002
#   batch 50 loss: 0.6276289224624634
#   batch 60 loss: 0.5958339929580688
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 6: LOSS train 0.5958 valid 0.6219 | Acc: 96.67%
# EPOCH 7:
#   batch 10 loss: 0.5984680473804473
#   batch 20 loss: 0.594134372472763
#   batch 30 loss: 0.5939972221851348
#   batch 40 loss: 0.6442775249481201
#   batch 50 loss: 0.5939778745174408
#   batch 60 loss: 0.6943672060966491
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 7: LOSS train 0.6944 valid 0.6347 | Acc: 96.67%
# EPOCH 8:
#   batch 10 loss: 0.5802822828292846
#   batch 20 loss: 0.6432473123073578
#   batch 30 loss: 0.6428497910499573
#   batch 40 loss: 0.5960204780101777
#   batch 50 loss: 0.5905811786651611
#   batch 60 loss: 0.6101178765296936
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 8: LOSS train 0.6101 valid 0.6112 | Acc: 100.00%
# EPOCH 9:
#   batch 10 loss: 0.6026190638542175
#   batch 20 loss: 0.5885257065296173
#   batch 30 loss: 0.6074620187282562
#   batch 40 loss: 0.5630393624305725
#   batch 50 loss: 0.566838413476944
#   batch 60 loss: 0.6693636000156402
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 9: LOSS train 0.6694 valid 0.5992 | Acc: 96.67%
# EPOCH 10:
#   batch 10 loss: 0.6303190767765046
#   batch 20 loss: 0.5627655327320099
#   batch 30 loss: 0.6099706828594208
#   batch 40 loss: 0.5787000060081482
#   batch 50 loss: 0.5911042392253876
#   batch 60 loss: 0.6188097417354583
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 10: LOSS train 0.6188 valid 0.6003 | Acc: 100.00%
# EPOCH 11:
#   batch 10 loss: 0.5754108488559723
#   batch 20 loss: 0.6251301646232605
#   batch 30 loss: 0.5670614898204803
#   batch 40 loss: 0.6188985109329224
#   batch 50 loss: 0.6157053530216217
#   batch 60 loss: 0.5718322098255157
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 11: LOSS train 0.5718 valid 0.5992 | Acc: 100.00%
# EPOCH 12:
#   batch 10 loss: 0.5857742011547089
#   batch 20 loss: 0.616011506319046
#   batch 30 loss: 0.560262405872345
#   batch 40 loss: 0.5682645320892334
#   batch 50 loss: 0.6085886061191559
#   batch 60 loss: 0.6174641430377961
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 12: LOSS train 0.6175 valid 0.5902 | Acc: 96.67%
# EPOCH 13:
#   batch 10 loss: 0.5924815177917481
#   batch 20 loss: 0.557714432477951
#   batch 30 loss: 0.6692208886146546
#   batch 40 loss: 0.5609361112117768
#   batch 50 loss: 0.6000302553176879
#   batch 60 loss: 0.603358519077301
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 13: LOSS train 0.6034 valid 0.6051 | Acc: 96.67%
# EPOCH 14:
#   batch 10 loss: 0.6520454287528992
#   batch 20 loss: 0.5962291240692139
#   batch 30 loss: 0.5841202020645142
#   batch 40 loss: 0.559330552816391
#   batch 50 loss: 0.5912909567356109
#   batch 60 loss: 0.5584028244018555
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 14: LOSS train 0.5584 valid 0.5859 | Acc: 100.00%
# EPOCH 15:
#   batch 10 loss: 0.5714090228080749
#   batch 20 loss: 0.6174007952213287
#   batch 30 loss: 0.5895067155361176
#   batch 40 loss: 0.6078743696212768
#   batch 50 loss: 0.5592594265937805
#   batch 60 loss: 0.5957124054431915
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 15: LOSS train 0.5957 valid 0.5878 | Acc: 96.67%
# EPOCH 16:
#   batch 10 loss: 0.599635225534439
#   batch 20 loss: 0.5877377450466156
#   batch 30 loss: 0.559777808189392
#   batch 40 loss: 0.6088958084583282
#   batch 50 loss: 0.6373790323734283
#   batch 60 loss: 0.5588636755943298
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 16: LOSS train 0.5589 valid 0.5916 | Acc: 96.67%
# EPOCH 17:
#   batch 10 loss: 0.6149428367614747
#   batch 20 loss: 0.5650764763355255
#   batch 30 loss: 0.5858766436576843
#   batch 40 loss: 0.5885080099105835
#   batch 50 loss: 0.5925996780395508
#   batch 60 loss: 0.5570997297763824
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 17: LOSS train 0.5571 valid 0.5814 | Acc: 96.67%
# EPOCH 18:
#   batch 10 loss: 0.5754397451877594
#   batch 20 loss: 0.6111748456954956
#   batch 30 loss: 0.5900091528892517
#   batch 40 loss: 0.5612268090248108
#   batch 50 loss: 0.5619524896144867
#   batch 60 loss: 0.6198452055454254
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 18: LOSS train 0.6198 valid 0.5853 | Acc: 96.67%
# EPOCH 19:
#   batch 10 loss: 0.5853197276592255
#   batch 20 loss: 0.5812627375125885
#   batch 30 loss: 0.6345689952373504
#   batch 40 loss: 0.59033282995224
#   batch 50 loss: 0.563010185956955
#   batch 60 loss: 0.5558945596218109
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 19: LOSS train 0.5559 valid 0.5819 | Acc: 96.67%
# EPOCH 20:
#   batch 10 loss: 0.5551845908164978
#   batch 20 loss: 0.5763026952743531
#   batch 30 loss: 0.6287889778614044
#   batch 40 loss: 0.584391075372696
#   batch 50 loss: 0.5555557489395142
#   batch 60 loss: 0.600100439786911
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 20: LOSS train 0.6001 valid 0.5818 | Acc: 96.67%
# EPOCH 21:
#   batch 10 loss: 0.5908553421497345
#   batch 20 loss: 0.5564635097980499
#   batch 30 loss: 0.5768837928771973
#   batch 40 loss: 0.5770404994487762
#   batch 50 loss: 0.6038285791873932
#   batch 60 loss: 0.5966833710670472
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 21: LOSS train 0.5967 valid 0.5840 | Acc: 96.67%
# EPOCH 22:
#   batch 10 loss: 0.5569311738014221
#   batch 20 loss: 0.555834686756134
#   batch 30 loss: 0.5780134558677673
#   batch 40 loss: 0.6376493990421295
#   batch 50 loss: 0.5805672705173492
#   batch 60 loss: 0.5851637780666351
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 22: LOSS train 0.5852 valid 0.5758 | Acc: 100.00%
# EPOCH 23:
#   batch 10 loss: 0.567574656009674
#   batch 20 loss: 0.6007095336914062
#   batch 30 loss: 0.6466068029403687
#   batch 40 loss: 0.5544260263442993
#   batch 50 loss: 0.5703617930412292
#   batch 60 loss: 0.5541653633117676
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 23: LOSS train 0.5542 valid 0.5787 | Acc: 96.67%
# EPOCH 24:
#   batch 10 loss: 0.5860567212104797
#   batch 20 loss: 0.5562345623970032
#   batch 30 loss: 0.5639769852161407
#   batch 40 loss: 0.5803069651126862
#   batch 50 loss: 0.5936457753181458
#   batch 60 loss: 0.5996189296245575
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 24: LOSS train 0.5996 valid 0.5847 | Acc: 96.67%
# EPOCH 25:
#   batch 10 loss: 0.6016987383365631
#   batch 20 loss: 0.5549726843833923
#   batch 30 loss: 0.5867178797721863
#   batch 40 loss: 0.6171926140785218
#   batch 50 loss: 0.5578236639499664
#   batch 60 loss: 0.5700197279453277
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 25: LOSS train 0.5700 valid 0.5761 | Acc: 100.00%
# EPOCH 26:
#   batch 10 loss: 0.5533922255039215
#   batch 20 loss: 0.6033532083034515
#   batch 30 loss: 0.5890905380249023
#   batch 40 loss: 0.5758605659008026
#   batch 50 loss: 0.5879035055637359
#   batch 60 loss: 0.5672679424285889
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 26: LOSS train 0.5673 valid 0.5779 | Acc: 96.67%
# EPOCH 27:
#   batch 10 loss: 0.5566506505012512
#   batch 20 loss: 0.567011547088623
#   batch 30 loss: 0.582606852054596
#   batch 40 loss: 0.6075271308422089
#   batch 50 loss: 0.5630647718906403
#   batch 60 loss: 0.5975288987159729
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 27: LOSS train 0.5975 valid 0.5756 | Acc: 96.67%
# EPOCH 28:
#   batch 10 loss: 0.564107471704483
#   batch 20 loss: 0.5762038767337799
#   batch 30 loss: 0.5654952228069305
#   batch 40 loss: 0.5514821350574494
#   batch 50 loss: 0.6522724270820618
#   batch 60 loss: 0.5561000406742096
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 28: LOSS train 0.5561 valid 0.5792 | Acc: 96.67%
# EPOCH 29:
#   batch 10 loss: 0.5723330438137054
#   batch 20 loss: 0.5938369631767273
#   batch 30 loss: 0.5524570882320404
#   batch 40 loss: 0.6018486082553863
#   batch 50 loss: 0.5549792528152466
#   batch 60 loss: 0.5951024115085601
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 29: LOSS train 0.5951 valid 0.5778 | Acc: 96.67%
# EPOCH 30:
#   batch 10 loss: 0.5539403975009918
#   batch 20 loss: 0.5895148754119873
#   batch 30 loss: 0.6090985238552094
#   batch 40 loss: 0.5619175136089325
#   batch 50 loss: 0.5921117663383484
#   batch 60 loss: 0.5688060998916626
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 30: LOSS train 0.5688 valid 0.5868 | Acc: 96.67%
# EPOCH 31:
#   batch 10 loss: 0.5533331632614136
#   batch 20 loss: 0.5594064593315125
#   batch 30 loss: 0.5577862739562989
#   batch 40 loss: 0.5555388689041137
#   batch 50 loss: 0.6457094073295593
#   batch 60 loss: 0.594499933719635
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 31: LOSS train 0.5945 valid 0.5711 | Acc: 100.00%
# EPOCH 32:
#   batch 10 loss: 0.5872319579124451
#   batch 20 loss: 0.5597088456153869
#   batch 30 loss: 0.5568628251552582
#   batch 40 loss: 0.5635270297527313
#   batch 50 loss: 0.6272189021110535
#   batch 60 loss: 0.572409063577652
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 32: LOSS train 0.5724 valid 0.5731 | Acc: 96.67%
# EPOCH 33:
#   batch 10 loss: 0.5987936437129975
#   batch 20 loss: 0.6326621115207672
#   batch 30 loss: 0.5518248736858368
#   batch 40 loss: 0.5722603261470794
#   batch 50 loss: 0.5580095171928405
#   batch 60 loss: 0.5887851417064667
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 33: LOSS train 0.5888 valid 0.5671 | Acc: 100.00%
# EPOCH 34:
#   batch 10 loss: 0.5541785776615142
#   batch 20 loss: 0.5656415402889252
#   batch 30 loss: 0.5949410498142242
#   batch 40 loss: 0.5542782127857209
#   batch 50 loss: 0.6462457656860352
#   batch 60 loss: 0.5564542829990387
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 34: LOSS train 0.5565 valid 0.5661 | Acc: 100.00%
# EPOCH 35:
#   batch 10 loss: 0.5925945580005646
#   batch 20 loss: 0.5567919313907623
#   batch 30 loss: 0.5643887400627137
#   batch 40 loss: 0.5755948781967163
#   batch 50 loss: 0.5883096098899842
#   batch 60 loss: 0.5763650238513947
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 35: LOSS train 0.5764 valid 0.5708 | Acc: 100.00%
# EPOCH 36:
#   batch 10 loss: 0.5715525031089783
#   batch 20 loss: 0.6161946833133698
#   batch 30 loss: 0.6013009369373321
#   batch 40 loss: 0.5524066388607025
#   batch 50 loss: 0.5886758506298065
#   batch 60 loss: 0.554713898897171
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 36: LOSS train 0.5547 valid 0.5701 | Acc: 100.00%
# EPOCH 37:
#   batch 10 loss: 0.5536050617694854
#   batch 20 loss: 0.5576032340526581
#   batch 30 loss: 0.5522892057895661
#   batch 40 loss: 0.5745110630989074
#   batch 50 loss: 0.5880103707313538
#   batch 60 loss: 0.6372710585594177
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 37: LOSS train 0.6373 valid 0.5678 | Acc: 100.00%
# EPOCH 38:
#   batch 10 loss: 0.5519017517566681
#   batch 20 loss: 0.6181275844573975
#   batch 30 loss: 0.5926917910575866
#   batch 40 loss: 0.5568436563014985
#   batch 50 loss: 0.5821638345718384
#   batch 60 loss: 0.5535598993301392
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 38: LOSS train 0.5536 valid 0.5644 | Acc: 100.00%
# EPOCH 39:
#   batch 10 loss: 0.5979428052902221
#   batch 20 loss: 0.5524794280529022
#   batch 30 loss: 0.5964094698429108
#   batch 40 loss: 0.5712995529174805
#   batch 50 loss: 0.5638040781021119
#   batch 60 loss: 0.5616434812545776
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 39: LOSS train 0.5616 valid 0.5631 | Acc: 100.00%
# EPOCH 40:
#   batch 10 loss: 0.5529331803321839
#   batch 20 loss: 0.5668487846851349
#   batch 30 loss: 0.5851296067237854
#   batch 40 loss: 0.5910599708557129
#   batch 50 loss: 0.5645702064037323
#   batch 60 loss: 0.5976071417331695
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 40: LOSS train 0.5976 valid 0.5650 | Acc: 100.00%
# EPOCH 41:
#   batch 10 loss: 0.5542524218559265
#   batch 20 loss: 0.5650989711284637
#   batch 30 loss: 0.5637536704540252
#   batch 40 loss: 0.6015885233879089
#   batch 50 loss: 0.5859681725502014
#   batch 60 loss: 0.5720839858055115
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 41: LOSS train 0.5721 valid 0.5652 | Acc: 100.00%
# EPOCH 42:
#   batch 10 loss: 0.5516969859600067
#   batch 20 loss: 0.5548847258090973
#   batch 30 loss: 0.5582575321197509
#   batch 40 loss: 0.5822665333747864
#   batch 50 loss: 0.6512913107872009
#   batch 60 loss: 0.5533773481845856
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 42: LOSS train 0.5534 valid 0.5784 | Acc: 96.67%
# EPOCH 43:
#   batch 10 loss: 0.562118798494339
#   batch 20 loss: 0.6016647398471833
#   batch 30 loss: 0.5584522724151612
#   batch 40 loss: 0.5840687394142151
#   batch 50 loss: 0.5532492220401763
#   batch 60 loss: 0.5984055399894714
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 43: LOSS train 0.5984 valid 0.5631 | Acc: 100.00%
# EPOCH 44:
#   batch 10 loss: 0.55800741314888
#   batch 20 loss: 0.6180273950099945
#   batch 30 loss: 0.5767152369022369
#   batch 40 loss: 0.5765676736831665
#   batch 50 loss: 0.5536223113536834
#   batch 60 loss: 0.5686835646629333
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 44: LOSS train 0.5687 valid 0.5614 | Acc: 100.00%
# EPOCH 45:
#   batch 10 loss: 0.5680169284343719
#   batch 20 loss: 0.5528116822242737
#   batch 30 loss: 0.5540962934494018
#   batch 40 loss: 0.5581217527389526
#   batch 50 loss: 0.6269216954708099
#   batch 60 loss: 0.5694399535655975
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 45: LOSS train 0.5694 valid 0.5702 | Acc: 96.67%
# EPOCH 46:
#   batch 10 loss: 0.5527444005012512
#   batch 20 loss: 0.6075204730033874
#   batch 30 loss: 0.5528561770915985
#   batch 40 loss: 0.552313482761383
#   batch 50 loss: 0.5527392148971557
#   batch 60 loss: 0.6294844508171081
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 46: LOSS train 0.6295 valid 0.5622 | Acc: 100.00%
# EPOCH 47:
#   batch 10 loss: 0.5582466185092926
#   batch 20 loss: 0.5899571239948272
#   batch 30 loss: 0.602017605304718
#   batch 40 loss: 0.5765763461589813
#   batch 50 loss: 0.5521637499332428
#   batch 60 loss: 0.5700132727622986
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 47: LOSS train 0.5700 valid 0.5714 | Acc: 96.67%
# EPOCH 48:
#   batch 10 loss: 0.5823459625244141
#   batch 20 loss: 0.5525790393352509
#   batch 30 loss: 0.5559011697769165
#   batch 40 loss: 0.552080774307251
#   batch 50 loss: 0.6039452075958252
#   batch 60 loss: 0.5958235025405884
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 48: LOSS train 0.5958 valid 0.5618 | Acc: 100.00%
# EPOCH 49:
#   batch 10 loss: 0.5561445951461792
#   batch 20 loss: 0.5856764137744903
#   batch 30 loss: 0.6005446374416351
#   batch 40 loss: 0.5537696063518525
#   batch 50 loss: 0.5534274637699127
#   batch 60 loss: 0.5807159304618835
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 49: LOSS train 0.5807 valid 0.5613 | Acc: 100.00%
# EPOCH 50:
#   batch 10 loss: 0.5772520482540131
#   batch 20 loss: 0.5633891224861145
#   batch 30 loss: 0.5543679893016815
#   batch 40 loss: 0.5642910122871398
#   batch 50 loss: 0.5695050239562989
#   batch 60 loss: 0.6029313981533051
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 50: LOSS train 0.6029 valid 0.5659 | Acc: 100.00%
# EPOCH 51:
#   batch 10 loss: 0.5531069278717041
#   batch 20 loss: 0.5516832649707795
#   batch 30 loss: 0.6470341980457306
#   batch 40 loss: 0.5733345687389374
#   batch 50 loss: 0.5585458219051361
#   batch 60 loss: 0.5618561446666718
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 51: LOSS train 0.5619 valid 0.5604 | Acc: 100.00%
# EPOCH 52:
#   batch 10 loss: 0.5550880432128906
#   batch 20 loss: 0.5749030351638794
#   batch 30 loss: 0.5993285953998566
#   batch 40 loss: 0.5534115493297577
#   batch 50 loss: 0.5601602494716644
#   batch 60 loss: 0.5847758173942565
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 52: LOSS train 0.5848 valid 0.5590 | Acc: 100.00%
# EPOCH 53:
#   batch 10 loss: 0.564003187417984
#   batch 20 loss: 0.5537503182888031
#   batch 30 loss: 0.5541433572769165
#   batch 40 loss: 0.6238444447517395
#   batch 50 loss: 0.5579785406589508
#   batch 60 loss: 0.5742970764636993
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 53: LOSS train 0.5743 valid 0.5627 | Acc: 100.00%
# EPOCH 54:
#   batch 10 loss: 0.5691740274429321
#   batch 20 loss: 0.5561902225017548
#   batch 30 loss: 0.5517678320407867
#   batch 40 loss: 0.5543264448642731
#   batch 50 loss: 0.5517735660076142
#   batch 60 loss: 0.642935186624527
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 54: LOSS train 0.6429 valid 0.5607 | Acc: 100.00%
# EPOCH 55:
#   batch 10 loss: 0.5548860192298889
#   batch 20 loss: 0.6197120845317841
#   batch 30 loss: 0.599376630783081
#   batch 40 loss: 0.5518802165985107
#   batch 50 loss: 0.6289154291152954
#   batch 60 loss: 0.5519052445888519
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# ...
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 82: LOSS train 0.6012 valid 0.5529 | Acc: 100.00%
# EPOCH 83:
#   batch 10 loss: 0.604805076122284
#   batch 20 loss: 0.556316077709198
#   batch 30 loss: 0.5622770011425018
#   batch 40 loss: 0.5520339369773865
#   batch 50 loss: 0.5516895055770874
#   batch 60 loss: 0.5529634296894074
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 83: LOSS train 0.5530 valid 0.5545 | Acc: 100.00%
# EPOCH 84:
#   batch 10 loss: 0.563923180103302
#   batch 20 loss: 0.6013863682746887
#   batch 30 loss: 0.5589884221553802
#   batch 40 loss: 0.5637911558151245
#   batch 50 loss: 0.551740163564682
#   batch 60 loss: 0.5516056478023529
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 84: LOSS train 0.5516 valid 0.5626 | Acc: 100.00%
# EPOCH 85:
#   batch 10 loss: 0.5516204118728638
#   batch 20 loss: 0.6121088087558746
#   batch 30 loss: 0.5518786251544953
#   batch 40 loss: 0.5593666195869446
#   batch 50 loss: 0.5672242283821106
#   batch 60 loss: 0.5530265867710114
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 85: LOSS train 0.5530 valid 0.5548 | Acc: 100.00%
# EPOCH 86:
#   batch 10 loss: 0.5626795291900635
#   batch 20 loss: 0.6018982887268066
#   batch 30 loss: 0.5515292346477508
#   batch 40 loss: 0.5531117737293243
#   batch 50 loss: 0.56457359790802
#   batch 60 loss: 0.5524800479412079
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 86: LOSS train 0.5525 valid 0.5535 | Acc: 100.00%
# EPOCH 87:
#   batch 10 loss: 0.5516493201255799
#   batch 20 loss: 0.5533255696296692
#   batch 30 loss: 0.601564210653305
#   batch 40 loss: 0.5672376811504364
#   batch 50 loss: 0.5515718519687652
#   batch 60 loss: 0.5538013994693756
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 87: LOSS train 0.5538 valid 0.5522 | Acc: 100.00%
# EPOCH 88:
#   batch 10 loss: 0.5589099764823914
#   batch 20 loss: 0.5516225755214691
#   batch 30 loss: 0.6015290558338166
#   batch 40 loss: 0.5569209814071655
#   batch 50 loss: 0.5535564124584198
#   batch 60 loss: 0.5561671853065491
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 88: LOSS train 0.5562 valid 0.5522 | Acc: 100.00%
# EPOCH 89:
#   batch 10 loss: 0.5519813597202301
#   batch 20 loss: 0.553199291229248
#   batch 30 loss: 0.5544088006019592
#   batch 40 loss: 0.6022379457950592
#   batch 50 loss: 0.5515354871749878
#   batch 60 loss: 0.5619678735733032
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 89: LOSS train 0.5620 valid 0.5526 | Acc: 100.00%
# EPOCH 90:
#   batch 10 loss: 0.5524098157882691
#   batch 20 loss: 0.5642023086547852
#   batch 30 loss: 0.5524836659431458
#   batch 40 loss: 0.6104048669338227
#   batch 50 loss: 0.5516567409038544
#   batch 60 loss: 0.5524706721305848
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 90: LOSS train 0.5525 valid 0.5529 | Acc: 100.00%
# EPOCH 91:
#   batch 10 loss: 0.5520311534404755
#   batch 20 loss: 0.5517039120197296
#   batch 30 loss: 0.5516611397266388
#   batch 40 loss: 0.5561867237091065
#   batch 50 loss: 0.60493084192276
#   batch 60 loss: 0.5597073674201966
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 91: LOSS train 0.5597 valid 0.5521 | Acc: 100.00%
# EPOCH 92:
#   batch 10 loss: 0.5520468115806579
#   batch 20 loss: 0.5570436894893647
#   batch 30 loss: 0.5520683050155639
#   batch 40 loss: 0.6064695119857788
#   batch 50 loss: 0.5541816413402557
#   batch 60 loss: 0.5515605986118317
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 92: LOSS train 0.5516 valid 0.5524 | Acc: 100.00%
# EPOCH 93:
#   batch 10 loss: 0.5523922860622406
#   batch 20 loss: 0.5557619988918304
#   batch 30 loss: 0.5516303300857544
#   batch 40 loss: 0.5520912766456604
#   batch 50 loss: 0.5570851802825928
#   batch 60 loss: 0.6031439423561096
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 93: LOSS train 0.6031 valid 0.5524 | Acc: 100.00%
# EPOCH 94:
#   batch 10 loss: 0.5557329833507538
#   batch 20 loss: 0.6018604218959809
#   batch 30 loss: 0.5521604418754578
#   batch 40 loss: 0.5516281843185424
#   batch 50 loss: 0.5565365076065063
#   batch 60 loss: 0.5515140950679779
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 94: LOSS train 0.5515 valid 0.5520 | Acc: 100.00%
# EPOCH 95:
#   batch 10 loss: 0.5527422606945038
#   batch 20 loss: 0.5535171926021576
#   batch 30 loss: 0.6016036331653595
#   batch 40 loss: 0.554694128036499
#   batch 50 loss: 0.5561198711395263
#   batch 60 loss: 0.5518305540084839
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 95: LOSS train 0.5518 valid 0.5524 | Acc: 100.00%
# EPOCH 96:
#   batch 10 loss: 0.5573823750019073
#   batch 20 loss: 0.5527506291866302
#   batch 30 loss: 0.6016121923923492
#   batch 40 loss: 0.5531561017036438
#   batch 50 loss: 0.5518001794815064
#   batch 60 loss: 0.5518260955810547
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 96: LOSS train 0.5518 valid 0.5522 | Acc: 100.00%
# EPOCH 97:
#   batch 10 loss: 0.6050860583782196
#   batch 20 loss: 0.5515696763992309
#   batch 30 loss: 0.5519163131713867
#   batch 40 loss: 0.5529781460762024
#   batch 50 loss: 0.5556304693222046
#   batch 60 loss: 0.5519395053386689
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 97: LOSS train 0.5519 valid 0.5525 | Acc: 100.00%
# EPOCH 98:
#   batch 10 loss: 0.5521195709705353
#   batch 20 loss: 0.5570966720581054
#   batch 30 loss: 0.5551890969276428
#   batch 40 loss: 0.5515103697776794
#   batch 50 loss: 0.5529612898826599
#   batch 60 loss: 0.6014131009578705
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 98: LOSS train 0.6014 valid 0.5523 | Acc: 100.00%
# EPOCH 99:
#   batch 10 loss: 0.5516210198402405
#   batch 20 loss: 0.6019061446189881
#   batch 30 loss: 0.5534906089305878
#   batch 40 loss: 0.5536466062068939
#   batch 50 loss: 0.5559131503105164
#   batch 60 loss: 0.5514728426933289
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 99: LOSS train 0.5515 valid 0.5518 | Acc: 100.00%
# EPOCH 100:
#   batch 10 loss: 0.5537301123142242
#   batch 20 loss: 0.5547719597816467
#   batch 30 loss: 0.5558962762355805
#   batch 40 loss: 0.6025220155715942
#   batch 50 loss: 0.5518344283103943
#   batch 60 loss: 0.5515154361724853
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 100: LOSS train 0.5515 valid 0.5518 | Acc: 100.00%

# %% [markdown]
# ## Mostrar alguna gráfica

# %%
plt.style.use('ggplot')
fig, (ax1, ax2) = plt.subplots(2, figsize=(12, 6), sharex=True)

ax1.plot(accuracy_list)
ax1.set_ylabel("validation accuracy")
ax2.plot(loss_list)
ax2.set_ylabel("validation loss")
ax2.set_xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# Gráfica de arriba:
# - La línea empieza abajo, cerca del 83%. Esto significa que, nada más empezar a entrenar, la red ya fue capaz de adivinar correctamente el 83% de las flores (unas 25 de 30)
# - Casi inmediatamente, la línea sube y se queda plana en la parte superior, alrededor del 96.6%. Esto te indica que tu modelo alcanzó su máximo aprendizaje muy rápido y se pasó casi todas las 100 épocas acertando 29 de las 30 flores de validación de forma constante.
# - Hay unas cuantas caídas en forma de "V" que bajan hasta el 93.3% aproximadamente. Son simplemente momentos puntuales donde la red tuvo una ligera duda matemática y falló una flor más (acertando 28 de 30). Es un comportamiento totalmente normal.
#
# Gráfica de abajo:
# - La pérdida (loss) mide cuánto se equivoca la red. Cuanto más bajo sea el número, mejor.
# - Al principio (época 0), el error es alto (casi 1.0) porque la red no sabe nada y está adivinando al azar. En las primeras 10 épocas, la curva cae en picado, lo que significa que la red está aprendiendo rapidísimo a identificar los patrones de las flores.
# - A partir de la época 40 aproximadamente, la línea se vuelve casi plana. Esto indica que el modelo ha convergido: ya ha aprendido todo lo que podía de esos datos y seguir entrenando más épocas apenas mejora el resultado.

# %% [markdown]
# ## Persistencia del Modelo (Exportación del state_dict)

# %%
# Definimos el nombre de la carpeta y creamos la ruta completa
carpeta_modelos = 'modelos'
ruta_archivo = os.path.join(carpeta_modelos, 'modelo_iris_entrenado.pth')

os.makedirs(carpeta_modelos, exist_ok=True)

# Guardamos el "cerebro" de la red en esa nueva ruta
torch.save(model.state_dict(), ruta_archivo)

print(f"¡Modelo guardado exitosamente en la ruta: {ruta_archivo}!")
# Out:
# ¡Modelo guardado exitosamente en la ruta: modelos\modelo_iris_entrenado.pth!

# %% [markdown]
# Una vez que la red neuronal ha finalizado su entrenamiento y hemos validado su precisión (alcanzando un ~96%), procedemos a guardar el conocimiento adquirido.
#
# Para evitar tener que reentrenar el modelo en cada ejecución, extraemos el `state_dict` de PyTorch (el diccionario que contiene los pesos y sesgos matemáticos ya optimizados) y lo exportamos como un archivo `.pth` en la carpeta `/modelos`. Esto nos permite cargar el cerebro de la red en cualquier momento para ponerla en producción y realizar nuevas predicciones.
