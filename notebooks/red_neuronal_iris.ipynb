# %% [markdown]
# # Tarea 69 - Iris Dataset
# Implementa usando PyTorch y siguiendo la domcumentación un clasificador para el dataset Iris.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

import torch
from torch.utils.data import Dataset

import torch.nn.functional as F
import torch.nn as nn
from torch.utils.data import random_split
from torch.utils.tensorboard import SummaryWriter

# %% [markdown]
# ## Pasos previos
# 1. Cargar o dataset
# 2. Esudiarlo: Ver algún dato, pintar alguna gráfica
# 3. Tranformación de datos

# %% [markdown]
# ### Importar dataset Iris

# %%
irisDataset = pd.read_csv("../data/iris/iris.data", #TODO: aperez: Poner dos puntos para que salga de notebooks y entre en data
                          names=["sepallength","sepalwidth",
                                 "petallength","petalwidth","class"])

# %% [markdown]
# ### Estudio dataset. Datos, mostrar gráficas...

# %%
irisDataset.head(4)
# Out:
#    sepallength  sepalwidth  petallength  petalwidth        class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa

# %%
plt.style.use('ggplot')
nomeClases = irisDataset["class"].unique()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for target, target_name in enumerate(nomeClases):
    X_plot = irisDataset[irisDataset["class"] == target_name]
    ax1.plot(X_plot["sepallength"], X_plot["sepalwidth"], 
             linestyle='none', 
             marker='o', 
             label=target_name)
ax1.set_xlabel("sepallength")
ax1.set_ylabel("sepalwidth")
ax1.axis('equal')
ax1.legend()

# %% [markdown]
# ### Trasformación de Datos

# %% [markdown]
# Para trabajar bien con los datos de una red de neuronas, tenenmos que hacer alguna que otra transformación en los datos de entrada
# - No podemos trabajar con entradas categóricas (class)
# - Los valores de entrada están mejor con media 0 y desviación típica 1
# Se puede hacer una clase que haga transformación del tipo de otro frameworks

# %%
class StandardScaler:

    def __init__(self, mean=None, std=None, epsilon=1e-7):
        """Standard Scaler.
        The class can be used to normalize PyTorch Tensors using native functions. The module does not expect the
        tensors to be of any specific shape; as long as the features are the last dimension in the tensor, the module
        will work fine.
        :param mean: The mean of the features. The property will be set after a call to fit.
        :param std: The standard deviation of the features. The property will be set after a call to fit.
        :param epsilon: Used to avoid a Division-By-Zero exception.
        """
        self.mean = mean
        self.std = std
        self.epsilon = epsilon
    def fit(self, values):
        dims = list(range(values.dim() - 1))
        self.mean = torch.mean(values, dim=dims)
        self.std = torch.std(values, dim=dims)
    def transform(self, values):
        return (values - self.mean) / (self.std + self.epsilon)

    def fit_transform(self, values):
        self.fit(values)
        return self.transform(values)

    def __repr__(self):
        return f"mean: {self.mean}, std:{self.std}, epsilon:{self.epsilon}"

# %% [markdown]
# ### Datasets en PyTorch

# %% [markdown]
# Para evitar que el código de lectura de datos se vuelva caótico y difícil de mantener, PyTorch centraliza este proceso usando Datasets y DataLoaders.
# - **El rol del Dataset**: Es el objeto responsable de almacenar, leer y adaptar la información. PyTorch no hace distinción entre sus Datasets predefinidos y los que tú decidas crear desde cero; ambos se tratan igual en el ecosistema.
# - **Creación de un Dataset personalizado**: Para hacer uno propio, debes crear una clase en Python que herede de torch.utils.data.Dataset.
# Esta clase personalizada debe implementar obligatoriamente tres métodos fundamentales:
# 1. __ init__: Es el constructor. Aquí debes leer los datos originales y dejarlos preparados en memoria.
# 2. __ len__: Debe devolver el número total de patrones o muestras que tiene tu conjunto de datos.
# 3. __ getitem__: Es el encargado de extraer y devolver un patrón o muestra individual cuando se le pide.

# %%
class IrisDataset(Dataset):
  def __init__(self, src_file, root_dir, transform=None):
    irisDataset = pd.read_csv(src_file, names=["sepallength","sepalwidth","petallength","petalwidth","class"])
    X = irisDataset[irisDataset.columns.intersection(["sepallength","sepalwidth","petallength","petalwidth"])]
    Y = irisDataset[irisDataset.columns.intersection(["class"])]
    nomeClases = Y["class"].unique()
    conversion = {v: k for k, v in dict(enumerate(nomeClases)).items()}
    YConversion = pd.DataFrame()
    for nome in nomeClases:
      YConversion[nome] = (Y["class"]==nome).apply(lambda x : 1.0 if x else 0.0)
    y_tensor = torch.as_tensor(YConversion.to_numpy()).type(torch.float32)
    df_dict = dict.fromkeys(X.columns, '')
    X.rename(columns = df_dict)
    s1=X.iloc[:,0:4].values
    x_tensor = torch.tensor(s1)
    scaler = StandardScaler()
    scaler.fit(x_tensor)
    XScalada = scaler.fit_transform(x_tensor).type(torch.float32)
    self.data = torch.cat((XScalada,y_tensor),1)
    self.root_dir = root_dir
    self.transform = transform
  def __len__(self):
    return len(self.data)

  def __getitem__(self, idx):
    if torch.is_tensor(idx):
      idx = idx.tolist()
    preds = self.data[idx, 0:4]
    spcs = self.data[idx, 4:]
    sample = (preds, spcs)
    if self.transform:
      sample = self.transform(sample)
    return sample

# %% [markdown]
# ### Carga de datos por IrisDataset

# %% [markdown]
# No viene mal acceder al primer elemento, por ver si algo sale mal

# %%
dataset = IrisDataset("../data/iris/iris.data",".")
display(dataset[0]) # comprobamos que sale algo
print(dataset.data.shape)
# Out:
# (tensor([-0.8977,  1.0286, -1.3368, -1.3086]), tensor([1., 0., 0.]))
# torch.Size([150, 7])

# %% [markdown]
# ## División en Train y Test
# - No se puede añadir elementos a untensor después de la creación
# - Pero podemos crear un nuevo tensor que una dos tensor, para eso está la función **cat**

# %%
lonxitudeDataset = len(dataset)
tamTrain =int(lonxitudeDataset*0.8)
tamVal = int(lonxitudeDataset*0.2)

train_set, val_set = random_split(dataset, [tamTrain, tamVal]) # TODO: aperez: Faltaba esta linea para futuros proyectos

print(f"Tam dataset: {lonxitudeDataset} train: {tamTrain} tamVal: {tamVal}")
train_ldr = torch.utils.data.DataLoader(train_set, batch_size=2,
    shuffle=True, drop_last=False)
# TODO: aperez: num_workers=2 -> S.O: Linux o macOS, PyTorch puede crear "clones" (forks) del proceso principal muy fácilmente para que carguen los datos en paralelo
#               En Windowns maneja el multiprocesamiento de forma diferente (usa algo llamado spawn). Al intentar crear estos subprocesos dentro de un Notebook, 
#               Windows se lía intentando recargar todo tu código desde cero, y los trabajadores colapsan. Ponemos a 0!!

# validation_loader =torch.utils.data.DataLoader(val_set, batch_size=4, shuffle=False, num_workers=2)
validation_loader =torch.utils.data.DataLoader(val_set, batch_size=4, shuffle=False, num_workers=0)
# Out:
# Tam dataset: 150 train: 120 tamVal: 30

# %% [markdown]
# ## Creación del Modelo
# - El modelo tiene que derivar de la clase **torch.nn.Module**
# - Deberiamos tener el método __ init__ y el método **forward**
#     - En init hay que definir la estructura del modelo: capas que tiene, tipo de capa, elementos en cada capa
#     - En forward hay que indicar como se hace el cálculo cara delante: a partir de una entrada obtener la salida

# %%
class Model(nn.Module):
    def __init__(self, input_dim):
        super(Model, self).__init__()
        self.layer1 = nn.Linear(input_dim, 50)
        self.layer2 = nn.Linear(50, 50)
        self.layer3 = nn.Linear(in_features=50, out_features=3)
        
    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        x = F.softmax(self.layer3(x), dim=1)
        return x

# %% [markdown]
# - Para las capas usamos *Linear*
#     - El primer parámetro es el tamaño de entrada
#     - El segundo parámetro es la salida
# - Para el cálculo de la salida usamos relu e softmax

# %% [markdown]
# ## Instanciar el Modelo
# - Una vez instanciado el modelo hay:
#     - Instanciarlo
#     - Definir el optimizador
#     - Definir la función de error
# - Para este dataset utilizaremos optimizadores **Adam** y **CrossEntropyLoss**

# %% [markdown]
# - Optimizador Adam: Ajusta los pesos de forma inteligente
# - Learning rate (lr): Tamaño do paso
#     - Con lr pequeña, necesitas más épocas para alcanzar un buen resultado
#     - Con lr más grande, puedes necesitar menos épocas, pero hay que vigilar que no diverja

# %%
model     = Model(4) #TODO: aperez: IMPORTANTE!! Tiene que coincidir con el número de características de entrada (features) que tiene cada patrón
                     # Al ser el datset de Iris , tiene 4 
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn   = nn.CrossEntropyLoss()
display(model)
# Out:
# Model(
#   (layer1): Linear(in_features=4, out_features=50, bias=True)
#   (layer2): Linear(in_features=50, out_features=50, bias=True)
#   (layer3): Linear(in_features=50, out_features=3, bias=True)
# )

# %% [markdown]
# ### Prueba
# No está de más probar que todo en este proceso encaja y hacer una simulación de una iteración de entrenamientoss

# %%
entradaProba,dest = next(iter(train_ldr))
print("Entrada:")
display(entradaProba)
print("Desexada:")
display(dest)
saida = model(entradaProba) # esta é a proba de verdade
print("Saída:")
display(saida)
loss_fn(saida, dest)
# Out:
# Entrada:
# tensor([[-0.7769,  1.0286, -1.2801, -1.3086],
#         [ 2.1214, -0.1245,  1.6103,  1.1811]])
# Desexada:
# tensor([[1., 0., 0.],
#         [0., 0., 1.]])
# Saída:
# tensor([[0.3000, 0.3348, 0.3652],
#         [0.3226, 0.3071, 0.3704]], grad_fn=<SoftmaxBackward0>)
# tensor(1.0971, grad_fn=<DivBackward1>)

# %% [markdown]
# ## Función de entrenamiento
# - Ahora se trata de hacer una función que haga una iteración simple de entrenamiento (epoch) sobre una entrada
#     -  Se recoge cada uno de los grupos de entrada
#         1. Separamos entre datos de entrada y salida deseada
#         2. Se pone los gradientes a cero
#         3. Se calcula la salida
#         4. Se calcula el error en la salida en las capas intermedias
#         5. Modificamos pesos
#         6. Capturamos información para informes

# %%
def train_one_epoch(epoch_index, tb_writer):
    running_loss = 0.
    last_loss = 0.
    # usamos enumerate para saber en que batch imos
    for i, data in enumerate(train_ldr):
        # Every data instance is an input + label pair
        inputs, labels = data
        # Zero your gradients for every batch!
        optimizer.zero_grad()
        # Make predictions for this batch
        outputs = model(inputs)
        # Compute the loss and its gradients
        loss = loss_fn(outputs, labels)
        loss.backward()
        # Adjust learning weights
        optimizer.step()
        # Gather data and report
        running_loss += loss.item()
        if i % 10 == 9:
            last_loss = running_loss / 10 # loss per batch
            print('  batch {} loss: {}'.format(i + 1, last_loss))
            running_loss = 0.
    return last_loss

# %% [markdown]
# - El entrenamiento consiste en ir pasando la función anterior unas cuantas veces en bucle y validando el entrenamiento con el test
# - El test se puede hacer al final o durante el propio entrenamiento (depende la información que queramos ver)

# %% [markdown]
# **Épocas(EPOCHS)**: Número de veces que el modelo ve todos los datos
# - Si la curva aun sube, se puede aumentar
# - Si está plana ya vale
#
# Se ve en *validation accuract* (gráfica paso siguiente)

# %%
EPOCHS = 100
loss_list     = torch.zeros((EPOCHS,))
accuracy_list = torch.zeros((EPOCHS,))
writer = SummaryWriter('runs/experimento_iris')
for epoch in range(EPOCHS):
    print('EPOCH {}:'.format(epoch + 1))

    # Poñemos o modelo en modo entrenamento
    model.train(True)
    avg_loss = train_one_epoch(epoch, writer)
    loss_list[epoch] = avg_loss
    # Non se precisan os gradientes para o test
    model.train(False)
    running_vloss = 0.0
    for i, vdata in enumerate(validation_loader):
        vinputs, vlabels = vdata
        voutputs = model(vinputs)
        vloss = loss_fn(voutputs, vlabels)

        print(f"Forma de voutputs: {voutputs.shape}")
        print(f"Forma de vlabels: {vlabels.shape}")

        # TODO: aperez: En clasificación, dim=1 nos da la clase ganadora para cada elemento del lote.
        correct = (torch.argmax(voutputs, dim=1) == torch.argmax(vlabels, dim=1)).type(torch.FloatTensor)
        accuracy_list[epoch] += correct.sum()
        running_vloss += vloss

    avg_vloss = running_vloss / (i + 1)
    accuracy_list[epoch] = (accuracy_list[epoch] / int(lonxitudeDataset*0.2)) * 100
    
    print('EPOCH {}: LOSS train {:.4f} valid {:.4f} | Acc: {:.2f}%'.format(
        epoch + 1, avg_loss, avg_vloss, accuracy_list[epoch]
    ))
# Out:
# EPOCH 1:
#   batch 10 loss: 1.0881863117218018
#   batch 20 loss: 1.0442893922328949
#   batch 30 loss: 1.0335440516471863
#   batch 40 loss: 0.959682434797287
#   batch 50 loss: 0.9519328832626343
#   batch 60 loss: 0.8929326415061951
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 1: LOSS train 0.8929 valid 0.8575 | Acc: 70.00%
# EPOCH 2:
#   batch 10 loss: 0.8409611284732819
#   batch 20 loss: 0.8116404294967652
#   batch 30 loss: 0.7568703651428222
#   batch 40 loss: 0.852416867017746
#   batch 50 loss: 0.7719317436218261
#   batch 60 loss: 0.7276811718940734
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 2: LOSS train 0.7277 valid 0.7616 | Acc: 73.33%
# EPOCH 3:
#   batch 10 loss: 0.8115099430084228
#   batch 20 loss: 0.7208420634269714
#   batch 30 loss: 0.6766755521297455
#   batch 40 loss: 0.684408986568451
#   batch 50 loss: 0.7208923697471619
#   batch 60 loss: 0.6816322982311249
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 3: LOSS train 0.6816 valid 0.7207 | Acc: 80.00%
# EPOCH 4:
#   batch 10 loss: 0.6840465068817139
#   batch 20 loss: 0.645873236656189
#   batch 30 loss: 0.6749553680419922
#   batch 40 loss: 0.6184010863304138
#   batch 50 loss: 0.7681385576725006
#   batch 60 loss: 0.6587265014648438
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 4: LOSS train 0.6587 valid 0.6820 | Acc: 86.67%
# EPOCH 5:
#   batch 10 loss: 0.6721740305423737
#   batch 20 loss: 0.6280504703521729
#   batch 30 loss: 0.644521850347519
#   batch 40 loss: 0.6690437197685242
#   batch 50 loss: 0.6438291192054748
#   batch 60 loss: 0.604973965883255
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 5: LOSS train 0.6050 valid 0.6422 | Acc: 96.67%
# EPOCH 6:
#   batch 10 loss: 0.6521741151809692
#   batch 20 loss: 0.6616350769996643
#   batch 30 loss: 0.6186819195747375
#   batch 40 loss: 0.5837207078933716
#   batch 50 loss: 0.582172030210495
#   batch 60 loss: 0.6370535790920258
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 6: LOSS train 0.6371 valid 0.6247 | Acc: 96.67%
# EPOCH 7:
#   batch 10 loss: 0.597683596611023
#   batch 20 loss: 0.6926176309585571
#   batch 30 loss: 0.613820594549179
#   batch 40 loss: 0.5964339137077331
#   batch 50 loss: 0.5721075236797333
#   batch 60 loss: 0.5925954937934875
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 7: LOSS train 0.5926 valid 0.6163 | Acc: 100.00%
# EPOCH 8:
#   batch 10 loss: 0.6092363059520721
#   batch 20 loss: 0.6187503814697266
#   batch 30 loss: 0.6037977457046508
#   batch 40 loss: 0.6122764527797699
#   batch 50 loss: 0.5635560810565948
#   batch 60 loss: 0.6240588426589966
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 8: LOSS train 0.6241 valid 0.6055 | Acc: 100.00%
# EPOCH 9:
#   batch 10 loss: 0.5944744765758514
#   batch 20 loss: 0.5668489933013916
#   batch 30 loss: 0.584494549036026
#   batch 40 loss: 0.6513763785362243
#   batch 50 loss: 0.6183501780033112
#   batch 60 loss: 0.5916882157325745
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 9: LOSS train 0.5917 valid 0.5928 | Acc: 96.67%
# EPOCH 10:
#   batch 10 loss: 0.5938179969787598
#   batch 20 loss: 0.5874051570892334
#   batch 30 loss: 0.5706439435482025
#   batch 40 loss: 0.5772756636142731
#   batch 50 loss: 0.6824807703495026
#   batch 60 loss: 0.5732907593250275
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 10: LOSS train 0.5733 valid 0.5951 | Acc: 100.00%
# EPOCH 11:
#   batch 10 loss: 0.5671147406101227
#   batch 20 loss: 0.6524179458618165
#   batch 30 loss: 0.628864711523056
#   batch 40 loss: 0.557985806465149
#   batch 50 loss: 0.5838116526603698
#   batch 60 loss: 0.5693318605422973
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 11: LOSS train 0.5693 valid 0.5812 | Acc: 100.00%
# EPOCH 12:
#   batch 10 loss: 0.5861994743347168
#   batch 20 loss: 0.6082846045494079
#   batch 30 loss: 0.5879069924354553
#   batch 40 loss: 0.5960624277591705
#   batch 50 loss: 0.586947762966156
#   batch 60 loss: 0.5753015995025634
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 12: LOSS train 0.5753 valid 0.5896 | Acc: 100.00%
# EPOCH 13:
#   batch 10 loss: 0.6388937473297119
#   batch 20 loss: 0.5667508244514465
#   batch 30 loss: 0.5786485791206359
#   batch 40 loss: 0.5610152840614319
#   batch 50 loss: 0.6387455999851227
#   batch 60 loss: 0.5545502007007599
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 13: LOSS train 0.5546 valid 0.5769 | Acc: 100.00%
# EPOCH 14:
#   batch 10 loss: 0.6003079950809479
#   batch 20 loss: 0.5943439900875092
#   batch 30 loss: 0.5666906774044037
#   batch 40 loss: 0.6104525625705719
#   batch 50 loss: 0.595327627658844
#   batch 60 loss: 0.5548933923244477
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 14: LOSS train 0.5549 valid 0.5743 | Acc: 100.00%
# EPOCH 15:
#   batch 10 loss: 0.5682017922401428
#   batch 20 loss: 0.642631322145462
#   batch 30 loss: 0.5540620267391205
#   batch 40 loss: 0.5848236560821534
#   batch 50 loss: 0.5618867754936219
#   batch 60 loss: 0.5902490735054016
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 15: LOSS train 0.5902 valid 0.5724 | Acc: 100.00%
# EPOCH 16:
#   batch 10 loss: 0.5555366694927215
#   batch 20 loss: 0.5641345322132111
#   batch 30 loss: 0.5665388524532318
#   batch 40 loss: 0.6362059056758881
#   batch 50 loss: 0.5848471462726593
#   batch 60 loss: 0.5986382842063904
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 16: LOSS train 0.5986 valid 0.5711 | Acc: 100.00%
# EPOCH 17:
#   batch 10 loss: 0.5702532708644867
#   batch 20 loss: 0.5539762318134308
#   batch 30 loss: 0.6128681778907776
#   batch 40 loss: 0.5795685529708863
#   batch 50 loss: 0.5655671000480652
#   batch 60 loss: 0.6200115501880645
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 17: LOSS train 0.6200 valid 0.5730 | Acc: 100.00%
# EPOCH 18:
#   batch 10 loss: 0.5550571322441101
#   batch 20 loss: 0.5600972831249237
#   batch 30 loss: 0.5804972290992737
#   batch 40 loss: 0.6041228473186493
#   batch 50 loss: 0.5982542276382447
#   batch 60 loss: 0.5802069246768952
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 18: LOSS train 0.5802 valid 0.5700 | Acc: 100.00%
# EPOCH 19:
#   batch 10 loss: 0.5532236278057099
#   batch 20 loss: 0.5712412655353546
#   batch 30 loss: 0.5830768346786499
#   batch 40 loss: 0.5633320987224579
#   batch 50 loss: 0.6050260543823243
#   batch 60 loss: 0.6381106495857238
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 19: LOSS train 0.6381 valid 0.5733 | Acc: 100.00%
# EPOCH 20:
#   batch 10 loss: 0.5810233056545258
#   batch 20 loss: 0.6123525619506835
#   batch 30 loss: 0.5727312922477722
#   batch 40 loss: 0.5594198048114777
#   batch 50 loss: 0.606663054227829
#   batch 60 loss: 0.5682917296886444
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 20: LOSS train 0.5683 valid 0.5672 | Acc: 100.00%
# EPOCH 21:
#   batch 10 loss: 0.6619689464569092
#   batch 20 loss: 0.5533656179904938
#   batch 30 loss: 0.5842595517635345
#   batch 40 loss: 0.5625063061714173
#   batch 50 loss: 0.5570135414600372
#   batch 60 loss: 0.5575308084487915
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 21: LOSS train 0.5575 valid 0.5682 | Acc: 100.00%
# EPOCH 22:
#   batch 10 loss: 0.5555532395839691
#   batch 20 loss: 0.5673769772052765
#   batch 30 loss: 0.6027605175971985
#   batch 40 loss: 0.5726972281932831
#   batch 50 loss: 0.6062795281410217
#   batch 60 loss: 0.5537273287773132
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 22: LOSS train 0.5537 valid 0.5663 | Acc: 100.00%
# EPOCH 23:
#   batch 10 loss: 0.5998796880245209
#   batch 20 loss: 0.6098737835884094
#   batch 30 loss: 0.5588482081890106
#   batch 40 loss: 0.5714938819408417
#   batch 50 loss: 0.5524919271469116
#   batch 60 loss: 0.5546206355094909
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 23: LOSS train 0.5546 valid 0.5657 | Acc: 100.00%
# EPOCH 24:
#   batch 10 loss: 0.5697856187820435
#   batch 20 loss: 0.5699062466621398
#   batch 30 loss: 0.6270897269248963
#   batch 40 loss: 0.5748755037784576
#   batch 50 loss: 0.5692003607749939
#   batch 60 loss: 0.558411157131195
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 24: LOSS train 0.5584 valid 0.5749 | Acc: 96.67%
# EPOCH 25:
#   batch 10 loss: 0.5649873495101929
#   batch 20 loss: 0.6381107866764069
#   batch 30 loss: 0.5557864785194397
#   batch 40 loss: 0.5521280527114868
#   batch 50 loss: 0.576589161157608
#   batch 60 loss: 0.5538692116737366
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 25: LOSS train 0.5539 valid 0.5633 | Acc: 100.00%
# EPOCH 26:
#   batch 10 loss: 0.6129555463790893
#   batch 20 loss: 0.566147756576538
#   batch 30 loss: 0.5656878173351287
#   batch 40 loss: 0.5812215387821198
#   batch 50 loss: 0.5526726484298706
#   batch 60 loss: 0.571685540676117
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 26: LOSS train 0.5717 valid 0.5653 | Acc: 100.00%
# EPOCH 27:
#   batch 10 loss: 0.5535967469215393
#   batch 20 loss: 0.5800637781620026
#   batch 30 loss: 0.558344978094101
#   batch 40 loss: 0.597190672159195
#   batch 50 loss: 0.5548667848110199
#   batch 60 loss: 0.6063759088516235
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 27: LOSS train 0.6064 valid 0.5766 | Acc: 96.67%
# EPOCH 28:
#   batch 10 loss: 0.556561142206192
#   batch 20 loss: 0.5540882349014282
#   batch 30 loss: 0.5551358520984649
#   batch 40 loss: 0.5556877076625824
#   batch 50 loss: 0.6436540961265564
#   batch 60 loss: 0.5764690399169922
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 28: LOSS train 0.5765 valid 0.5671 | Acc: 100.00%
# EPOCH 29:
#   batch 10 loss: 0.5765941560268402
#   batch 20 loss: 0.5654926538467407
#   batch 30 loss: 0.5794338107109069
#   batch 40 loss: 0.5592522025108337
#   batch 50 loss: 0.5972139537334442
#   batch 60 loss: 0.568841016292572
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 29: LOSS train 0.5688 valid 0.5834 | Acc: 96.67%
# EPOCH 30:
#   batch 10 loss: 0.5898529648780823
#   batch 20 loss: 0.6026746094226837
#   batch 30 loss: 0.5679449677467346
#   batch 40 loss: 0.5517088770866394
#   batch 50 loss: 0.5534543573856354
#   batch 60 loss: 0.6150607287883758
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 30: LOSS train 0.6151 valid 0.5599 | Acc: 100.00%
# EPOCH 31:
#   batch 10 loss: 0.6019860208034515
#   batch 20 loss: 0.5651314318180084
#   batch 30 loss: 0.5624539852142334
#   batch 40 loss: 0.557704746723175
#   batch 50 loss: 0.5663072943687439
#   batch 60 loss: 0.5659771680831909
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 31: LOSS train 0.5660 valid 0.5630 | Acc: 100.00%
# EPOCH 32:
#   batch 10 loss: 0.6012869358062745
#   batch 20 loss: 0.55314199924469
#   batch 30 loss: 0.5781945049762726
#   batch 40 loss: 0.5587306141853332
#   batch 50 loss: 0.5646670699119568
#   batch 60 loss: 0.5783524811267853
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 32: LOSS train 0.5784 valid 0.5732 | Acc: 96.67%
# EPOCH 33:
#   batch 10 loss: 0.5568331241607666
#   batch 20 loss: 0.554132741689682
#   batch 30 loss: 0.5660265982151031
#   batch 40 loss: 0.5734940826892853
#   batch 50 loss: 0.5568690955638885
#   batch 60 loss: 0.6159446120262146
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 33: LOSS train 0.6159 valid 0.5775 | Acc: 96.67%
# EPOCH 34:
#   batch 10 loss: 0.5739186465740204
#   batch 20 loss: 0.5525447130203247
#   batch 30 loss: 0.5543668389320373
#   batch 40 loss: 0.6268340706825256
#   batch 50 loss: 0.5554794728755951
#   batch 60 loss: 0.5546818494796752
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 34: LOSS train 0.5547 valid 0.5810 | Acc: 96.67%
# EPOCH 35:
#   batch 10 loss: 0.5534822285175324
#   batch 20 loss: 0.5911199569702148
#   batch 30 loss: 0.5527949333190918
#   batch 40 loss: 0.6022392094135285
#   batch 50 loss: 0.5847818076610565
#   batch 60 loss: 0.552184921503067
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 35: LOSS train 0.5522 valid 0.5643 | Acc: 100.00%
# EPOCH 36:
#   batch 10 loss: 0.5697978436946869
#   batch 20 loss: 0.5587108850479126
#   batch 30 loss: 0.5578990817070008
#   batch 40 loss: 0.5519749164581299
#   batch 50 loss: 0.6150108397006988
#   batch 60 loss: 0.5587765455245972
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 36: LOSS train 0.5588 valid 0.5629 | Acc: 100.00%
# EPOCH 37:
#   batch 10 loss: 0.5695944786071777
#   batch 20 loss: 0.5516013443470001
#   batch 30 loss: 0.555228978395462
#   batch 40 loss: 0.5658052504062653
#   batch 50 loss: 0.5619056284427643
#   batch 60 loss: 0.6188268184661865
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 37: LOSS train 0.6188 valid 0.5799 | Acc: 96.67%
# EPOCH 38:
#   batch 10 loss: 0.5520440638065338
#   batch 20 loss: 0.5564444839954377
#   batch 30 loss: 0.5527065634727478
#   batch 40 loss: 0.6131048500537872
#   batch 50 loss: 0.567843759059906
#   batch 60 loss: 0.5689188957214355
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 38: LOSS train 0.5689 valid 0.5788 | Acc: 96.67%
# EPOCH 39:
#   batch 10 loss: 0.5565564692020416
#   batch 20 loss: 0.5766573131084443
#   batch 30 loss: 0.5541387796401978
#   batch 40 loss: 0.5518431246280671
#   batch 50 loss: 0.5615544497966767
#   batch 60 loss: 0.6038188815116883
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 39: LOSS train 0.6038 valid 0.5786 | Acc: 96.67%
# EPOCH 40:
#   batch 10 loss: 0.554692006111145
#   batch 20 loss: 0.5527504861354828
#   batch 30 loss: 0.6093091130256653
#   batch 40 loss: 0.5662259340286255
#   batch 50 loss: 0.5580930233001709
#   batch 60 loss: 0.5551323592662811
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 40: LOSS train 0.5551 valid 0.5733 | Acc: 96.67%
# EPOCH 41:
#   batch 10 loss: 0.5547041952610016
#   batch 20 loss: 0.5560869812965393
#   batch 30 loss: 0.5757207930088043
#   batch 40 loss: 0.5517012000083923
#   batch 50 loss: 0.5617775619029999
#   batch 60 loss: 0.6026329278945923
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 41: LOSS train 0.6026 valid 0.5759 | Acc: 96.67%
# EPOCH 42:
#   batch 10 loss: 0.5570146918296814
#   batch 20 loss: 0.5522376954555511
#   batch 30 loss: 0.5613933026790618
#   batch 40 loss: 0.6136000573635101
#   batch 50 loss: 0.5577472746372223
#   batch 60 loss: 0.5645647883415222
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 42: LOSS train 0.5646 valid 0.5814 | Acc: 96.67%
# EPOCH 43:
#   batch 10 loss: 0.5591862380504609
#   batch 20 loss: 0.551770955324173
#   batch 30 loss: 0.5525043189525605
#   batch 40 loss: 0.5517279922962188
#   batch 50 loss: 0.601828420162201
#   batch 60 loss: 0.5962427377700805
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 43: LOSS train 0.5962 valid 0.5818 | Acc: 96.67%
# EPOCH 44:
#   batch 10 loss: 0.5528149902820587
#   batch 20 loss: 0.5890696763992309
#   batch 30 loss: 0.5516646146774292
#   batch 40 loss: 0.5587676405906677
#   batch 50 loss: 0.5666706025600433
#   batch 60 loss: 0.5995748102664947
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 44: LOSS train 0.5996 valid 0.5834 | Acc: 96.67%
# EPOCH 45:
#   batch 10 loss: 0.5538910448551178
#   batch 20 loss: 0.5663834810256958
#   batch 30 loss: 0.5538552641868592
#   batch 40 loss: 0.551766836643219
#   batch 50 loss: 0.5619426012039185
#   batch 60 loss: 0.6080709397792816
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 45: LOSS train 0.6081 valid 0.5805 | Acc: 96.67%
# EPOCH 46:
#   batch 10 loss: 0.6047170221805572
#   batch 20 loss: 0.5598601698875427
#   batch 30 loss: 0.5545786321163177
#   batch 40 loss: 0.569505774974823
#   batch 50 loss: 0.5515265345573426
#   batch 60 loss: 0.5520322263240814
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 46: LOSS train 0.5520 valid 0.5839 | Acc: 96.67%
# EPOCH 47:
#   batch 10 loss: 0.5551057815551758
#   batch 20 loss: 0.5656714797019958
#   batch 30 loss: 0.602903151512146
#   batch 40 loss: 0.5522572457790375
#   batch 50 loss: 0.5551429033279419
#   batch 60 loss: 0.5533013880252838
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 47: LOSS train 0.5533 valid 0.5771 | Acc: 96.67%
# EPOCH 48:
#   batch 10 loss: 0.5690306901931763
#   batch 20 loss: 0.55156911611557
#   batch 30 loss: 0.5528112113475799
#   batch 40 loss: 0.602000892162323
#   batch 50 loss: 0.5548190176486969
#   batch 60 loss: 0.5539173662662507
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 48: LOSS train 0.5539 valid 0.5803 | Acc: 96.67%
# EPOCH 49:
#   batch 10 loss: 0.5620933949947358
#   batch 20 loss: 0.5532045960426331
#   batch 30 loss: 0.552921199798584
#   batch 40 loss: 0.5998496532440185
#   batch 50 loss: 0.55581134557724
#   batch 60 loss: 0.5593787968158722
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 49: LOSS train 0.5594 valid 0.5805 | Acc: 96.67%
# EPOCH 50:
#   batch 10 loss: 0.5546872735023498
#   batch 20 loss: 0.552093243598938
#   batch 30 loss: 0.5547261655330658
#   batch 40 loss: 0.6014187574386597
#   batch 50 loss: 0.5590247213840485
#   batch 60 loss: 0.5590765595436096
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 50: LOSS train 0.5591 valid 0.5824 | Acc: 96.67%
# EPOCH 51:
#   batch 10 loss: 0.6107040882110596
#   batch 20 loss: 0.5520815491676331
#   batch 30 loss: 0.5515451490879059
#   batch 40 loss: 0.5584138810634613
#   batch 50 loss: 0.5575684070587158
#   batch 60 loss: 0.5522357285022735
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 51: LOSS train 0.5522 valid 0.5810 | Acc: 96.67%
# EPOCH 52:
#   batch 10 loss: 0.5539406657218933
#   batch 20 loss: 0.5571631789207458
#   batch 30 loss: 0.5515187501907348
#   batch 40 loss: 0.5515052080154419
#   batch 50 loss: 0.6015792310237884
#   batch 60 loss: 0.5657351911067963
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 52: LOSS train 0.5657 valid 0.5824 | Acc: 96.67%
# EPOCH 53:
#   batch 10 loss: 0.5571980595588684
#   batch 20 loss: 0.5554897964000702
#   batch 30 loss: 0.551643842458725
#   batch 40 loss: 0.5542656898498535
#   batch 50 loss: 0.5534824430942535
#   batch 60 loss: 0.6071327149868011
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 53: LOSS train 0.6071 valid 0.5821 | Acc: 96.67%
# EPOCH 54:
#   batch 10 loss: 0.5540762960910797
#   batch 20 loss: 0.5515682101249695
#   batch 30 loss: 0.6012002468109131
#   batch 40 loss: 0.5557423055171966
#   batch 50 loss: 0.5563044428825379
#   batch 60 loss: 0.5590137958526611
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 54: LOSS train 0.5590 valid 0.5822 | Acc: 96.67%
# EPOCH 55:
#   batch 10 loss: 0.60108283162117
#   batch 20 loss: 0.5569368422031402
#   batch 30 loss: 0.5619571030139923
#   batch 40 loss: 0.5535388112068176
#   batch 50 loss: 0.551502239704132
#   batch 60 loss: 0.5527059137821198
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# ...
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 82: LOSS train 0.5528 valid 0.5829 | Acc: 96.67%
# EPOCH 83:
#   batch 10 loss: 0.5527995705604554
#   batch 20 loss: 0.5534059047698975
#   batch 30 loss: 0.6014729678630829
#   batch 40 loss: 0.552042442560196
#   batch 50 loss: 0.5514589846134186
#   batch 60 loss: 0.5514904618263244
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 83: LOSS train 0.5515 valid 0.5830 | Acc: 96.67%
# EPOCH 84:
#   batch 10 loss: 0.5519266724586487
#   batch 20 loss: 0.5514942288398743
#   batch 30 loss: 0.5520954668521881
#   batch 40 loss: 0.5519811391830445
#   batch 50 loss: 0.5526278793811799
#   batch 60 loss: 0.6018212258815765
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 84: LOSS train 0.6018 valid 0.5830 | Acc: 96.67%
# EPOCH 85:
#   batch 10 loss: 0.5527126789093018
#   batch 20 loss: 0.6014179825782776
#   batch 30 loss: 0.5518604993820191
#   batch 40 loss: 0.5514709234237671
#   batch 50 loss: 0.551839017868042
#   batch 60 loss: 0.5525005877017974
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 85: LOSS train 0.5525 valid 0.5828 | Acc: 96.67%
# EPOCH 86:
#   batch 10 loss: 0.6016169428825379
#   batch 20 loss: 0.5524376273155213
#   batch 30 loss: 0.5517506659030914
#   batch 40 loss: 0.5520274460315704
#   batch 50 loss: 0.5518378853797913
#   batch 60 loss: 0.5519801020622254
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 86: LOSS train 0.5520 valid 0.5828 | Acc: 96.67%
# EPOCH 87:
#   batch 10 loss: 0.5516872644424439
#   batch 20 loss: 0.5515249609947205
#   batch 30 loss: 0.5515553891658783
#   batch 40 loss: 0.5517389953136445
#   batch 50 loss: 0.6018608093261719
#   batch 60 loss: 0.5532394230365754
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 87: LOSS train 0.5532 valid 0.5828 | Acc: 96.67%
# EPOCH 88:
#   batch 10 loss: 0.5516893804073334
#   batch 20 loss: 0.5517740786075592
#   batch 30 loss: 0.6019227564334869
#   batch 40 loss: 0.5522340774536133
#   batch 50 loss: 0.5520556747913361
#   batch 60 loss: 0.5515702605247498
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 88: LOSS train 0.5516 valid 0.5831 | Acc: 96.67%
# EPOCH 89:
#   batch 10 loss: 0.5520400106906891
#   batch 20 loss: 0.5518329620361329
#   batch 30 loss: 0.5517563998699189
#   batch 40 loss: 0.5514554023742676
#   batch 50 loss: 0.5515610694885253
#   batch 60 loss: 0.6030265986919403
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 89: LOSS train 0.6030 valid 0.5828 | Acc: 96.67%
# EPOCH 90:
#   batch 10 loss: 0.6021139204502106
#   batch 20 loss: 0.5526985466480255
#   batch 30 loss: 0.5514714419841766
#   batch 40 loss: 0.5518214762210846
#   batch 50 loss: 0.5515153288841248
#   batch 60 loss: 0.551451426744461
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 90: LOSS train 0.5515 valid 0.5830 | Acc: 96.67%
# EPOCH 91:
#   batch 10 loss: 0.5521297454833984
#   batch 20 loss: 0.5518000245094299
#   batch 30 loss: 0.5519081354141235
#   batch 40 loss: 0.5518630146980286
#   batch 50 loss: 0.6018891930580139
#   batch 60 loss: 0.5514538764953614
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 91: LOSS train 0.5515 valid 0.5828 | Acc: 96.67%
# EPOCH 92:
#   batch 10 loss: 0.5514956414699554
#   batch 20 loss: 0.5517880916595459
#   batch 30 loss: 0.5514757394790649
#   batch 40 loss: 0.5532625317573547
#   batch 50 loss: 0.6017277121543885
#   batch 60 loss: 0.5514527857303619
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 92: LOSS train 0.5515 valid 0.5835 | Acc: 96.67%
# EPOCH 93:
#   batch 10 loss: 0.5518312752246857
#   batch 20 loss: 0.5518660962581634
#   batch 30 loss: 0.5515711724758148
#   batch 40 loss: 0.6014161527156829
#   batch 50 loss: 0.5522490441799164
#   batch 60 loss: 0.5523134589195251
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 93: LOSS train 0.5523 valid 0.5829 | Acc: 96.67%
# EPOCH 94:
#   batch 10 loss: 0.5523709654808044
#   batch 20 loss: 0.551450377702713
#   batch 30 loss: 0.5518873870372772
#   batch 40 loss: 0.6014917314052581
#   batch 50 loss: 0.5517088651657105
#   batch 60 loss: 0.5519033670425415
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 94: LOSS train 0.5519 valid 0.5829 | Acc: 96.67%
# EPOCH 95:
#   batch 10 loss: 0.5517396211624146
#   batch 20 loss: 0.551561838388443
#   batch 30 loss: 0.5519933760166168
#   batch 40 loss: 0.551453459262848
#   batch 50 loss: 0.6015975534915924
#   batch 60 loss: 0.5524496257305145
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 95: LOSS train 0.5524 valid 0.5829 | Acc: 96.67%
# EPOCH 96:
#   batch 10 loss: 0.5524149298667907
#   batch 20 loss: 0.5517379522323609
#   batch 30 loss: 0.5514574170112609
#   batch 40 loss: 0.5518208980560303
#   batch 50 loss: 0.6015635550022125
#   batch 60 loss: 0.5519111752510071
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 96: LOSS train 0.5519 valid 0.5831 | Acc: 96.67%
# EPOCH 97:
#   batch 10 loss: 0.6015982031822205
#   batch 20 loss: 0.5516740560531617
#   batch 30 loss: 0.5523356914520263
#   batch 40 loss: 0.5515174269676208
#   batch 50 loss: 0.5514620125293732
#   batch 60 loss: 0.551885437965393
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 97: LOSS train 0.5519 valid 0.5830 | Acc: 96.67%
# EPOCH 98:
#   batch 10 loss: 0.5514869809150695
#   batch 20 loss: 0.5517342567443848
#   batch 30 loss: 0.551542192697525
#   batch 40 loss: 0.5514811456203461
#   batch 50 loss: 0.6015149593353272
#   batch 60 loss: 0.55272336602211
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 98: LOSS train 0.5527 valid 0.5830 | Acc: 96.67%
# EPOCH 99:
#   batch 10 loss: 0.5518681943416596
#   batch 20 loss: 0.5514573872089386
#   batch 30 loss: 0.5523628234863281
#   batch 40 loss: 0.6016667366027832
#   batch 50 loss: 0.5514751970767975
#   batch 60 loss: 0.5517537295818329
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 99: LOSS train 0.5518 valid 0.5828 | Acc: 96.67%
# EPOCH 100:
#   batch 10 loss: 0.551691734790802
#   batch 20 loss: 0.5527310788631439
#   batch 30 loss: 0.5514749705791473
#   batch 40 loss: 0.5514603137969971
#   batch 50 loss: 0.6019452452659607
#   batch 60 loss: 0.5514860391616822
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([4, 3])
# Forma de vlabels: torch.Size([4, 3])
# Forma de voutputs: torch.Size([2, 3])
# Forma de vlabels: torch.Size([2, 3])
# EPOCH 100: LOSS train 0.5515 valid 0.5830 | Acc: 96.67%

# %% [markdown]
# ## Mostrar alguna gráfica

# %%
plt.style.use('ggplot')
fig, (ax1, ax2) = plt.subplots(2, figsize=(12, 6), sharex=True)

ax1.plot(accuracy_list)
ax1.set_ylabel("validation accuracy")
ax2.plot(loss_list)
ax2.set_ylabel("validation loss")
ax2.set_xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# Gráfica de arriba:
# - La línea empieza abajo, cerca del 83%. Esto significa que, nada más empezar a entrenar, la red ya fue capaz de adivinar correctamente el 83% de las flores (unas 25 de 30)
# - Casi inmediatamente, la línea sube y se queda plana en la parte superior, alrededor del 96.6%. Esto te indica que tu modelo alcanzó su máximo aprendizaje muy rápido y se pasó casi todas las 100 épocas acertando 29 de las 30 flores de validación de forma constante.
# - Hay unas cuantas caídas en forma de "V" que bajan hasta el 93.3% aproximadamente. Son simplemente momentos puntuales donde la red tuvo una ligera duda matemática y falló una flor más (acertando 28 de 30). Es un comportamiento totalmente normal.
#
# Gráfica de abajo:
# - La pérdida (loss) mide cuánto se equivoca la red. Cuanto más bajo sea el número, mejor.
# - Al principio (época 0), el error es alto (casi 1.0) porque la red no sabe nada y está adivinando al azar. En las primeras 10 épocas, la curva cae en picado, lo que significa que la red está aprendiendo rapidísimo a identificar los patrones de las flores.
# - A partir de la época 40 aproximadamente, la línea se vuelve casi plana. Esto indica que el modelo ha convergido: ya ha aprendido todo lo que podía de esos datos y seguir entrenando más épocas apenas mejora el resultado.

# %% [markdown]
# ## Persistencia del Modelo (Exportación del state_dict)

# %%
# Definimos el nombre de la carpeta y creamos la ruta completa
carpeta_modelos = 'modelos'
ruta_archivo = os.path.join(carpeta_modelos, 'modelo_iris_entrenado.pth')

os.makedirs(carpeta_modelos, exist_ok=True)

# Guardamos el "cerebro" de la red en esa nueva ruta
torch.save(model.state_dict(), ruta_archivo)

print(f"¡Modelo guardado exitosamente en la ruta: {ruta_archivo}!")
# Out:
# ¡Modelo guardado exitosamente en la ruta: modelos\modelo_iris_entrenado.pth!

# %% [markdown]
# Una vez que la red neuronal ha finalizado su entrenamiento y hemos validado su precisión (alcanzando un ~96%), procedemos a guardar el conocimiento adquirido.
#
# Para evitar tener que reentrenar el modelo en cada ejecución, extraemos el `state_dict` de PyTorch (el diccionario que contiene los pesos y sesgos matemáticos ya optimizados) y lo exportamos como un archivo `.pth` en la carpeta `/modelos`. Esto nos permite cargar el cerebro de la red en cualquier momento para ponerla en producción y realizar nuevas predicciones.

# %% [markdown]
# ## Predicción del modelo

# %%
# Cargamos los datos originales y los convertimos a TENSOR de PyTorch
df_original = pd.read_csv("../data/iris/iris.data", names=["sepallength","sepalwidth","petallength","petalwidth","class"])
s1_original = df_original.iloc[:, 0:4].values
X_original_tensor = torch.tensor(s1_original, dtype=torch.float32)

# Entrenamos escalador personalizado para que recuerde las medias y desviaciones
scaler = StandardScaler()
scaler.fit(X_original_tensor) 

# Cargamos el modelo
modelo_cargado = model.__class__(4) 
modelo_cargado.load_state_dict(torch.load('modelos/modelo_iris_entrenado.pth'))
modelo_cargado.eval()

# Nuestras medidas en crudo (centímetros reales) pasadas a TENSOR
medidas_inventadas = torch.tensor([[5.1, 3.5, 1.3, 0.2]], dtype=torch.float32)

# Transformamos los centímetros usando tu escalador
tensor_entrada = scaler.transform(medidas_inventadas).type(torch.float32)

# Hacemos la predicción
with torch.no_grad():
    prediccion_bruta = modelo_cargado(tensor_entrada)
    clase_ganadora = torch.argmax(prediccion_bruta, dim=1).item()

# Extraemos el nombre exacto de la flor usando tu propia lógica
nombres_flores = df_original["class"].unique()
flor_predicha = nombres_flores[clase_ganadora]

print(f"Medidas en centímetros: {medidas_inventadas.tolist()[0]}")
print(f"Medidas escaladas (lo que ve la red): {tensor_entrada.tolist()[0]}")
print(f"¡La red neuronal está segura de que es una: {flor_predicha}!")
# Out:
# Medidas en centímetros: [5.099999904632568, 3.5, 1.2999999523162842, 0.20000000298023224]
# Medidas escaladas (lo que ve la red): [-0.8976743817329407, 1.0286107063293457, -1.3934696912765503, -1.3085925579071045]
# ¡La red neuronal está segura de que es una: Iris-setosa!
